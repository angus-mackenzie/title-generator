# %% [markdown]
# # Title Generation using Recurrent Neural Networks
# I never know what I should title most things I have written. I hope that by using a corpus of titles, recurrent neural networks (RNNs) can write my titles for me.
#
# I thought a fitting title to generate would be something within Machine Learning, so I used [Publish or Perish](https://harzing.com/resources/publish-or-perish) to fetch any title from Google Scholar associated with *Machine Learning*. It retrieved 950 titles, which you can view [here](https://gist.github.com/AngusTheMack/defadcbc503e2d625720661e9893ff0a).
#
# If you want to use this to  generate your own titles (or any text whatsoever), just change the `url` to download the data from, or the `save_location` to where your data is stored.
#
# ## Titles Generated
# During the time playing around with the implementations below I was able to gain some very cool sounding titles:
#   * Function Classification Using Machine Learning Techniques
#   * Bayesian Approximation of Effective Machine Learning
#   * Data Classification With Machine Learning
#   * Computer Multi-agent Boltzmann Machine Learning
#   * Machine Learning Approaches for Visual Classification
#   * New Machine Learning for Astrophysics
#   * Neural Machine Learning for Medical Imaging
#   * Deep Similarity Learning Filters
#
# ## Implementations
# I wanted to compare results between somewhat vanilla RNN implementations and a Long Short Term Memory (LSTM) model. To that end I used a character level RNN, word level RNN and a LSTM. This was done mainly to try and better understand the underlying concepts in RNNs, and what differentiates them from LSTMs.
#
# I used [Andrej Karpathy's blog](https://karpathy.github.io/) post [The Unreasonable Effectiveness of Recurrent Neural Networks ](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) as my starting point - and utilised his amazing [112 line char level RNN](https://gist.github.com/karpathy/d4dee566867f8291f086) implemented in vanilla python.
#
# After that I used [Denny Britz's](https://github.com/dennybritz) [word level RNN](https://github.com/dennybritz/rnn-tutorial-rnnlm/blob/master/RNNLM.ipynb) from his series of [blogspost](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-2-implementing-a-language-model-rnn-with-python-numpy-and-theano/) on the topic.
#
# Finally, I used [Shivam Bansal's](https://www.kaggle.com/shivamb) [Beginners Guide to Text Generation using LSTMs](https://www.kaggle.com/shivamb/beginners-guide-to-text-generation-using-lstms/notebook) for the LSTM implementation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import string
import urllib.request
import pickle
# %matplotlib inline

# %%
def download_data(url, save_location):
    """
    Download data to be used as corpus
    """
    print('Beginning file download...')  
    urllib.request.urlretrieve(url,save_location)
    print("Downloaded file, saving to:",save_location)

def load_data(save_location):
    """
    Load data from Textfile
    """
    file = open(save_location,"r")
    data = file.read()
    return data

def avg_char_per_title(data):
    """
    Calculate the average number of chars in a title for the sequence length
    """
    lines = data.split("\n")
    line_lengths = np.zeros(len(lines))
    for i,line in enumerate(lines):
        line_lengths[i] = len(line)
    return np.average(line_lengths)
        

def save_object(obj, filename):
    """
    Save an object - used to save models
    """
    with open(filename, 'wb') as output:
        pickle.dump(obj, output, -1)

# %%
# Change the URL to whatever text you want to train with
url = "https://gist.githubusercontent.com/AngusTheMack/defadcbc503e2d625720661e9893ff0a/raw/bb978a5ef025ff104009ab8139da4a0b7367992f/Titles.txt"

# Save Location will be used to load the data in
save_location = "Titles.txt" # either the name of the file downloaded with the URL above, or the location of your own file to load in

# %%
# Downloads the data, and loads it in
download_data(url,save_location)
data = load_data(save_location)
# Out:
# Beginning file download...
# Downloaded file, saving to: Titles.txt

# %%
# Print first 100 characters of the data
print(data[:100])
# Out:
# Scikit-learn: Machine learning in Python
# Pattern recognition and machine learning
# Gaussian processes

# %%
def clean_text(data):
    """
    Removes non essential characters in corpus of text
    """
    data = "".join(v for v in data if v not in string.punctuation).lower()
    data = data.encode("utf8").decode("ascii",'ignore')
    return data

# %%
# You don't need to clean, but it can make things simpler
cleaned = clean_text(data)
print(cleaned[:100])
# Out:
# scikitlearn machine learning in python
# pattern recognition and machine learning
# gaussian processes i

# %%
def unique_chars(data):
    """
    Get all unique Characters in the Dataset
    """
    return list(set(data))

# %%
# Some info about the data
chars = unique_chars(cleaned)
data_size, input_size = len(cleaned), len(chars)
print("Data has %d characters, %d of them are unique" % (data_size, input_size))
# Out:
# Data has 64663 characters, 36 of them are unique

# %%
def tokenize_chars(chars):
    """
    Create dictionaries to make it easy to convert from tokens to chars
    """
    char_to_idx = {ch:i for i,ch in enumerate(chars)}
    idx_to_char = {i:ch for i,ch in enumerate(chars)}
    return char_to_idx, idx_to_char

# %%
# Create dictionaries, and display example using 11 chars
char_to_idx, idx_to_char = tokenize_chars(chars)
first_title = cleaned[:11]
print("{0:<2}|{1:<2}".format('Character', 'Index'))
print("________________")
for i in range(len(first_title)):
    char_index = char_to_idx[first_title[i]]
    print("{0:<9}|{a:d}".format(idx_to_char[char_index], a=char_to_idx[first_title[i]]))
# Out:
# Character|Index
# ________________
# s        |12
# c        |28
# i        |29
# k        |19
# i        |29
# t        |7
# l        |2
# e        |18
# a        |9
# r        |10
# n        |6

# %% [markdown]
# # Char Level RNN
# Created by Andrej Karpathy, available here:  [here](https://gist.github.com/karpathy/d4dee566867f8291f086)

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License

Ever so slightly modified to be used with the above code
"""
data = cleaned
chars = unique_chars(cleaned)
data_size, vocab_size = len(cleaned), len(chars)

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_idx[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_idx[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(idx_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  wzaobr1wn1v0i1s4dfxsy nzzhacv6wnmx3h3al4rdeuuau5s36la1gv
# wpoucjnqgg1zwc1qy7ug 6gmn3jr0 7mxr07 ls3
# bzrjcrjd0g12g nrb00fzrnxeyfturlbrrmxuiq5vccy 61om
# auqwdaepa5g1atew
# o6kqtu0pyu72ikrlqdqu5vripn a
# 7e6q1
# ----
# iter 0, loss: 89.587970
# ----
#  ieetaihi mkn r pareutm shierulunetanec aem nept  ren lsigne7
# er metenetahhveceyem l gayepgrehatn2enaa ieiop pnnti lslecelom
# tjnet mew dtiestmeaoi 4ensl lcidiereeon
# i rhi h rnipi  sctiebh  lng senniem
# ----
# iter 100, loss: 90.192833
# ----
#  oa
# fghic7tn0tmtatenabcna wiaeprlcsaalsrs fele ea1hyah r inearfro tnrd rand
# d hiagee ntefghrtooieetnpnaea s fearp
# aeaeeuesenptkafysii trwiu nea t liama  renaupibsa
# rgmpopealcy ynaaaurd
# aeor5e  llirryf
# ----
# iter 200, loss: 88.911862
# ----
#   iaamrale fsloi iarrestioe aarm eacniniareconaghin leueapinarbiago atacokakheama   yingoinrae rannine le yn  aranve
# smaahneaonirt n
# as riggioaulerntee leatinm leineec aunn7ess 4aealalcorcnineala les a
# ----
# iter 300, loss: 87.089974
# ----
#  oocmapllroooofrnalgtaalile tcarpw
# seorie
# arooc
# takmesrif mopnersaesst bathitainentteati oe fhlirg aeacliatecsrin m t ulecarereteaehinecma
# fining  harningpsitine pflliengs k pitxnels reinecwecrsinn vha
# ----
# iter 400, loss: 84.868410
# ----
#  sog rcmathingarpe
# rac lg d anse sticeremone tiinimw nin rnisine mmtaloonfawcon frorn  skinim  s le mfores em bcarcing gachoados uhleix aral rtionpmrp earninginmtet
# ing a achincutacz regirbpaomeprontel
# ----
# iter 500, loss: 82.531505
# ----
#  assdmolachine leann lrteang ine facvaebeand
# carn dachgt mit lg
# reosonatnachocaluan na mong le psibe pomotilet learneues acseque asery mele
# g omapge marr m0 le nearnine tinblilg ilotp treysgoinaingteso
# ----
# iter 600, loss: 80.323878
# ----
#  mled
# if riclrenrofaplys coaint
# g xfcesraapn apr machine masr
# roachis intprtwr lene
# le rasinemearhings oenore
# n talojtea d fatecha mingsimtrwr lgcureatrif mss mfith medhdeerdibeds ining s
# adine sd mast
# ----
# iter 700, loss: 78.047678
# ----
#  insiteafl
# bachianglretine learn
# esd maheymaron carpharndectiomorotp ltinotescyise urn  leditpralidibeus papnpriterexv eseuleadicoelueline ldid menprecarptoapcruiticl wicra ndisict d mjanine sfss annw
# ----
# iter 800, loss: 76.076179
# ----
#  ine heacimearmoa viog thwi leachinet attaches in int arusisigs faatind hines him dts hiation mtaefnsacoin letivuatoire lealatechine
# lestsarn moarnint dale
# ning cabhaciay ine lebon parong tza alvicing
# ----
# iter 900, loss: 73.965779
# ----
#  apulearning
# memthin le6stor dinc
# dast ati heaning nething mpsimor qom foaching rearn vare
# loonion atmadviva poathont bachine
# ioonteoc licealn sechfod amaoniwyt a nine eaching pleaning loadublerls malt
# ----
# iter 1000, loss: 72.171908
# ----
#  a proation las dichdy mersing alolas did mel
# 7fcarnigsepks va damquchde
# apiniua pa h
# vos crs
# initorn
# learn feu s achine seruol amjpbio talihia0ume ron lachong ine lechsango te mf leonmd metsine chrnec
# ----
# iter 1100, loss: 70.246853
# ----
#  ainngelat l amstorud sl ingrp iny mscheletar ge chs
# toardegting vating lealtine ovibe onca learning alpeme fering in lsvistetiseine uret
# uthathicaseane om mathing lpeningy md l lpwetorg moraind chachs
# ----
# iter 1200, loss: 68.709041
# ----
#   machine loaprearle ly
# machine fuubisd liate leatoe atoaticainticoleprod
# ningdering arod decut rn om leaning eapiood tedobss moapring peached far ficta pihoul facg encereneapntiapinaleal machrnang fon
# ----
# iter 1300, loss: 67.246818
# ----
#  a parn teacand mparningeos insbs
# in iny foreing acal
# amachine pelatoriseopimtesstionyres boletiss reline dellasin
# sicarsrycina toapltare s fo maltoetrteopiefr edudyte ofisc prochuonstinsisen atering
# a
# ----
# iter 1400, loss: 65.799171
# ----
#  e asma prrema
# ne
# l re rygvive le podaatmoncatt asystidacerma d tecring appram farel achiacterchdiyt ueded machingrarn ganpadetiegarve rematew
# aprar toor mechio leachine retrecpteorich roactine fo ufin
# ----
# iter 1500, loss: 64.600454
# ----
#  amag sptemrcin fion ss cheation sestine rorcsootioatieinesss oncht riction
# ersle aleanthaind s oplasf apprecafing mr achine leachinelel wsty mapgnig maching lachine learoo iplensiting mina setictechni
# ----
# iter 1600, loss: 63.260430
# ----
#  pl htarpr foine linden tearnt ssins
# hacoloiamacthsetion maplin sretoin wpreretion eontithathing mankent monal verins
# acfi frearsis tipr uliog perh
# wi learningeagacti0n aller atoalernessung seog ge tea
# ----
# iter 1700, loss: 62.153038
# ----
#   fsesestka minthyyinit ycard ang machine mfescor prychivicoule onim m
# solatyinit ede dacrd ef id oncamfima manwicl apet pled mbad matomrarc learpron inng
# leatio e mascchon sapr de leatine leannedysiin
# ----
# iter 1800, loss: 60.973972
# ----
#  l aro mechine leachini leannd maslealnitioarente mpsedytitfistidiq
# arn appleaciog paldenetu emicing aneturion
# ammcam fomretronctinsuo de lemathe li eahs dytar th tororecht on f
# montaonudius
# peatoine a
# ----
# iter 1900, loss: 59.784977
# ----
#  e l s dioptisime restine intes songussleditsetrie wach of s fion mang leatlerar eines sederortechbechtaledis
# s4tachosive micchine liagnin pawator mabes wativi leacingssebl sofation cinng ancamamfi bic
# ----
# iter 2000, loss: 58.913404
# ----
#  disd mattoop
# fi miterrgasuon
# akfttearing inijealgolna atioa gorystousginsitis
# gr dios musesicuriqis
# arnictaconsssing
# omr detagningtiset0ra f bidation s foroch3inc udalogeteachegetrpy foifustioqy dar s
# ----
# iter 2100, loss: 57.965062
# ----
#  atino5 ftmefimazcushy ches ssing
# mathid chesl carnd tosecfatioasbator wras peulurs bt dirsch
# felacion foz  dersturry
# cocticalle learning sgmin alid loancive machinegr unedibstsening mcceplearning marn
# ----
# iter 2200, loss: 57.154533
# ----
#  onelea pem
# xprantest acision oagzic la mathros anticend picosiang maction
# sgvasution fens learning l achinileation asprforetticid inn
# machine laand
# sstion ucarceaclofors antho dicion popsichenog lemap
# ----
# iter 2300, loss: 56.407502
# ----
#  nn mascis macsing eson macepresiont afice peotosts toragon machpoimitucnmarticts ufoints
# aprobmosrchrear massion machine learning in how honon ithraangel es ndd srctro fs
# ledatiog rp in fla ecchon mac
# ----
# iter 2400, loss: 55.618905
# ----
#  urt setinacxppreco berening
# terr cing
# uratoamang dersied latorterts tem yeas fachis fopemiangpucangerechteger tered adsba
# angh abat ind alninesinge mbalgigerines mos
# assppr machine litimelming sid yte
# ----
# iter 2500, loss: 54.892110
# ----
#  r enmatre sding ande4in mactine learning leapnepledy thoation
# onectal learntivitiateethed learstoad machine porems beswit madesting uror gy de cal ustine prov machine laasd acamarce bmecppropred chev
# ----
# iter 2600, loss: 54.284710
# ----
#  tudection or on amcasest
# de machize learning aptoatorngenma for chemtertitidalite machine leyritno eigk
# ethemate on machine arn meetion udeseste pobe fh fere rearn ve festire reardimg machine mechine
# ----
# iter 2700, loss: 53.354186
# ----
#  dams an delertlevada he lachine wial
# ar appcoma nemminetrepndibk codet fo leatoine prorssestion da learning
# nopeemation upra teartion
# acotho learning d peaplaleide ans od cile machine learnine learnin
# ----
# iter 2800, loss: 52.475724
# ----
#  tors grantich in learnistfiatine t uve accoring aprantimitationor ir
# fes ind prral anmaditheburortesing learningrec n of fos mechine learale rlanaling maxhine leacok seankictieg machingion
# anvicoris a
# ----
# iter 2900, loss: 51.783431
# ----
#  ant pros tointarnit ancarviss learning urt d of michines scalt nearnon umacbtora kcacopred tofi decytiee awotiont chaststewrif
# tin staclingal desuvess machine ly learnpnine toathcuchsettima demacumols
# ----
# iter 3000, loss: 51.238139
# ----
#  thywors
# fiss machine l ne tionl apprsion machion kerrolterid cicy
# machin learridy
# oatnon pltarndw ctas
# actve machine leroane torycsing tora prciamann siteinturs machine l mich oeneltice fomt uasincsem
# ----
# iter 3100, loss: 50.641033
# ----
#  teal
# manthortion mechla tedes ol kxrorict
# inelyeaprsomly boctyisolelibimk
# aprecting atoorictoro mang mesdiswitecn learoningl machine learning tealtirn learning ufornt innve baca
# onet manatimatorih foa
# ----
# iter 3200, loss: 50.382811
# ----
#  estoatiog mathiog preinicvist aotecstinec malroxa woqod machine rnatufpedotufricale sexl eprgorits
# macanng vatats
# datwiog oaching apingar far sufache toaring sevila mang machine y monta munitem forece
# ----
# iter 3300, loss: 49.935147
# ----
#  rning dy on techma wor reb ons
# ads foro fa arnenticion
# achving
# foate machiqe liagectrocstion ladanid mphteras cech nmatiof beoledore in aprach machingerlapleag bysste machine learliqselelearnini learn
# ----
# iter 3400, loss: 49.652122
# ----
#  ceple tomolive boatetedysicive letervion smmataliling serte  leans taguaples bamictiossing empprod o sith antalsing sing al mlgartra le fifem machcing cascore pronty urpli sent
# deowem inthas matkine m
# ----
# iter 3500, loss: 49.243736
# ----
#  eglare le reumle cata cetices
# on a machine learning mastion
# ansemiths
# eslos prode trumonttor uprdiwrstoms ina pecpinigwe be for pensivew plemchdi tbe t mating machine
# eleleapriul red of ompealitas
# fev
# ----
# iter 3600, loss: 48.937850
# ----
#  omrtienvich liqe2goinid miand terroriching andaching mechine learding tovadiontalith satem machine lostofm tealgimos
# machine learning fhspemor atorowitas fe tichcti sna merenifdityth chtreccion toovec
# ----
# iter 3700, loss: 48.527714
# ----
#  g ds
# sctics
# wotian tiachion bach apspor arn fhs weching aen afoinissime machmags sss mgsyacap fecboitubtrs
# d cexti hedy icissing aring cospom cecring
# on sdis be shin ha
# ution in d pros wone ms
# chid te
# ----
# iter 3800, loss: 48.455603
# ----
#   ma pugors ipanstmc amactive terthening iny
# melamade forys
# rea intes nd mral cadeog baticg asdang prys ning mlasreteus muchofstoa md farying penancs fieemreteving inn und ty asthenge oforics sus wrati
# ----
# iter 3900, loss: 48.297695
# ----
#  tolen and sichon of arcocarqow
# arqmiongesmecoch d ussugetavioxuc dive cang redar ox sidty ind befursbuing perys mathing beand maleritercor feanna fe leathing omemete ness t mentifa uprappe tmank achop
# ----
# iter 4000, loss: 48.133534
# ----
#  on ancuplagacadite machine learning learn wicle paching ef machine learning adsemzatifawiz learning
# arppraeted fative osed miction l acpiveastitheat ve omlama ppmarnisperates inlearning annestin og ua
# ----
# iter 4100, loss: 48.091837
# ----
#   machine learsch faliba
# edeasing bpur apppromlithewive frsting
# bar dicnd comros ansfid shdic signi f ure machine luardib onuvor csengimattrtrochif danisecneulithe epwroltachw sustegpation putia thed t
# ----
# iter 4200, loss: 47.867950
# ----
#   prodetraration learning cartuantrincs
# ardic mechio  machone malerliur acing precests
# urcarning foxrratora andennd and febled maching
# beul atamofimalgestine learning inare tor ar atlicuss leand
# fangam
# ----
# iter 4300, loss: 47.676731
# ----
#  gec atwizes
# terent urchocoroing
# anifhteector erondiatine liarmas ed motargechg dialititem
# bengricion anucmata fe wotroblcard schaptiangurtache nabeoling toosicereannd msccing ins machine learning
# anc
# ----
# iter 4400, loss: 47.460099
# ----
#  of anmteme peppreitabpemewuritof litenach nithumate lema fion dacuds ieleation wase sparzing aned d learnin ion fateos tororumaction wochuvi mipeplarel cunase matareterercasive sebytusipneoturo liapps
# ----
# iter 4500, loss: 47.223705
# ----
#  threationlalet donuale roaduction eud machine tartytion seta theagion aplics dis urcor atoiniaderonbios un urdunend nd pyattos fory mepront prine pernu pus
# tovora
# atoroc on dems puprasveation mathiac
# ----
# iter 4600, loss: 46.969639
# ----
#  unank alein uchtion fiqus apuna
# teonine lisiog mechine learninga aplalengertlicet aning erator inbulicriog tepmars
# apalanny
# madars onctiank
# learning rechction dechmont athon ma chrach tomt
# rearkx on c
# ----
# iter 4700, loss: 46.819075
# ----
#  lonpwsinatione momal fe bemaled
# mabdeskesdal estif ofesorc cedumernsofsime las usplox  predichid agm untivy machin learning
# of fieasige mechinipreyrofiog sroms of asctrating ofl ex dapprora nupracunm
# ----
# iter 4800, loss: 46.762686
# ----
#  id catodom machine learcriel ureinste machinel ma annes stmariqe
# ofople foolsma liformath andentfogty machine loapros epris for and and muwicorenc optbrorlaclestionlocry dase
# to ext date preog
# machine
# ----
# iter 4900, loss: 46.573020
# ----
#  y ddul mochin seficd motred dad of learning
# tabapport bingsriteml anadetestackh chpulis qa urditarnet
# peninsing machine learning cochre ofmacvex
# machine liter machrion fod proctesleg minucecticg boact
# ----
# iter 5000, loss: 46.366803
# ----
#  nnveng trohtha aning machine learning ter machnber fop machine learning machine selarimutha
# fbsistine gronleradid mathiy and cvatiep reac arnaty mabated assauny tandictine reloifided snine apnawge fev
# ----
# iter 5100, loss: 46.277319
# ----
#  ation in urenseagnatasing wolecting omoatiof maching
# ateatuing reqoengrewasind learning
# ava mparing a 40ungoute tucayn andet ledynaticicych the machine umabgetry laruansi ennet fhone a curapins appar
# ----
# iter 5200, loss: 46.101478
# ----
#  sectining mechringr comedet dechin
# eneskifurion ucns onsyme fronin mephparevus loarning of learndxpemasize learningtent machine lpuroetas utrals
# insums dadase m onesicngernugexkwh machine la phetyna
# d
# ----
# iter 5300, loss: 45.652784
# ----
#  ekida wbadomerdiqfiol machine loarnincer chearniz sh bertectina mechine learning
# aftinm machanne neal
# parng insion witer anut s pnchs lelachine
# learning for tor the thochtyesch fut in andewromthcrmenp
# ----
# iter 5400, loss: 45.302834
# ----
#  a mrkach mactine learhing
# and laalselima forett va cositaspse oforthuva
# urontive s
# or tions
# pringhs machine liagle ulearticivg scaltitalentalemorec mcodastution urepicros
# in enkic reatiperr extooneati
# ----
# iter 5500, loss: 44.922869
# ----
#  g oflic treds geogsion machine learning
# aputhrattianteal hemachive withech machine learing althivact ggo ofeltiont epramerte ratore eling unengicadelassid axation wechnuns
# aves applo tangiles on machi
# ----
# iter 5600, loss: 44.762337
# ----
#  ste seachcilgsr prod ronsetes alaning ve ang colalsing
# ands
# alideritica
# fya mpacnitacpect mechonelgiol in bi toroltleas
# ony magig elemr mechine le6hing mamciba chal fover eltite d ol amperenthation an
# ----
# iter 5700, loss: 44.658246
# ----
#  smortrabsing pousbiioh recaling apin teackm malaratusutima u
# machine lerewroding
# dedethosebiale ur le aticate leyret onteriting e preanuifion apingars  odttationc learning in machine learn os detpow u
# ----
# iter 5800, loss: 44.648896
# ----
#  pti methy betecting acticling aryitrecriqu machine lerrnanusdiquifoprecenicsien caroing
# mdtrid pnomutitas mexhct sestima gensbyutererial scaticn deveryesginatufarith in andes
# precs cingereding fya fyt
# ----
# iter 5900, loss: 44.568964
# ----
#  lossing alefenudial jackine learning
# nitentase outes aplertiang acalein2iteur
# alioncrabactice fomardatifisting
# apdatizantkls yssizanwicg s uapperimgtroctionsmating achnewtordedid andsifiziqme tmow ont
# ----
# iter 6000, loss: 44.521049
# ----
#  mrasite learning lerranu msewiming machine leap5ina learningl
# inss tizatiess outt mapulor quaching arn cucoring gpinal machinel exixlalg of machine rearning angida
# mruragioaleandite machine learnite m
# ----
# iter 6100, loss: 44.345939
# ----
#  pnybinalsions
# torectyctection sysiterusler tercs inumreticine learniqe singalteation
# skfcass sptialuinlewror menplereltinaty relimathonocs
# aml epregurs foution in praluctor sithabf hofretorors sind ma
# ----
# iter 6200, loss: 44.296212
# ----
#  e s mactiones ins goti licating wus in athebans se sdastbastem for
# femmate finacions udestat
# michmma machine learninger
# anstr asin learn h usim te presaltires en larcusing machine suorycsdse sonictiqe
# ----
# iter 6300, loss: 44.188601
# ----
#  on profutenting ancalsion pplurres of enstoricncisiting learing acnach for apre cucectionetuin
# ti shing ousprira form ffarsegerrs foars actoxjest
# intast anix machine l acpels of ma hine alter fas fog
# ----
# iter 6400, loss: 44.274641
# ----
#   techming ann
# ppleriatifellabnetic thin mesfiol
# in ystabed masppomlask for machine learning uronticaplen aring a forecenicstine sestyris ting ing angtuconpicatficen kervicor lalliont berorimg
# viok met
# ----
# iter 6500, loss: 44.323359
# ----
#  ne machine learning reactifate of ardimable elthaltiolos an arning anvemr aplgach machine peel covesrore machine learning widation reargmicg atec michine learning
# boactwion ind semaxdichals poangiteng
# ----
# iter 6600, loss: 44.421743
# ----
#  aringy machine learning thox ma upreanspif encma s macuon pregrecetror machine learnider fex and machine mlare penchrocion prechstinusid anv bross
# midsion achis fore inkezasing sudigla dobaliad
# terecq
# ----
# iter 6700, loss: 44.549754
# ----
#  unensenddeltfores itionatec hates ds
# arfersiof of rearatiog
# reablation machine learning athehion angalsergst
# on deutud ba rutla machining mechongation excorgorcoltorot lerector ua faoe rxeztor er kons
# ----
# iter 6800, loss: 44.452816
# ----
#   apre sppomfame gefeichom learnor
# arvicer arn machine leactivibine metalgiatuosofias pratica bo mechile abated ot tears y toagvach mebrios ofuti indens
# nealenturog ccustimeskive toared speps machine l
# ----
# iter 6900, loss: 44.394816
# ----
#  iqacach
# od tevivexmity
# umadistum mathife metechlearning
# calakde altary qychaty seteltion bins arcorol agnyck machive the machine learning comectiox atr fera remavetesemurith
# d troskasuwization oachine
# ----
# iter 7000, loss: 44.328137
# ----
#  r stsetevihse carnsseonecisalk upptordo ticaty cstoonution soals and thariline learning machineleeran
# exhifionior eachine luarg for batkor integnid machine learnalip arna approrovizate salal ind monec
# ----
# iter 7100, loss: 44.155577
# ----
#  qes fols pjoterwactions for for relogenence prror mathoutor sing extatu aleinconn mrti baturl assictemankl machine learnong foreurranfaticn acation mattion tevivask
# d codtal of machine la foromaringl
# ----
# iter 7200, loss: 44.091919
# ----
#   learning
# and wool msctorsorcti sitic in leyciing mecwing
# aenveu bamabasd for ac witis albifawiasming
# in dan sroinsiction machine learninglear d proul anbratimiconning cofuctinitien
# learning
# dimanicon
# ----
# iter 7300, loss: 43.949044
# ----
#  apnimer dachs foichmalelt vit macy for
# cose matector uls machine learning athenfieg machine learning
# anchinghrmaned learning thonshipanesing pholctalepringiad did exprea rpedp menfiss machinelary of a
# ----
# iter 7400, loss: 44.099614
# ----
#  ornecpission alalyedigy prcepgor thanhs sthocestion
# swina fmachine learning aparnate legr machine learnge intpratuvimedorona spules utlaticn yople schsledyessing anmaticang dofroret ink andias propran
# ----
# iter 7500, loss: 43.984109
# ----
#  emetriacen sepreinen creltratoingutien machine learning wephedy appril dechin se rnatasif seqe cticsutico learning edond reandesesris machine learning leallices
# ind diansis machine
# learnini learning
# r
# ----
# iter 7600, loss: 43.856163
# ----
#  arning cczarnd alinasisusesiing
# alngont in machine legyt ine sinchmas anser enuhrmpprion uted mprapliegipas apte setusion asing ga dalicls
# danesing  cppiluleglgord ly wynann dars mppricleelesmal sppa
# ----
# iter 7700, loss: 43.908668
# ----
#  thiqupro atzare cors pwetucth
# ampledrowithy sdsentucsing sescanp fore predarith msutilg
# ang reapitertarns
# sucw debwicsel pronoutimase re mated sproard machiner asing
# rehrstomationberm pring int sefrco
# ----
# iter 7800, loss: 43.723235
# ----
#  hine liantieleprimolgyerion arnacker of datiof ba scacto
# reor machipe urlis ch debenged thonid cling of selmation exhangvicueine for
# fe vers apbros acheachineore ache3evem
# er and machine learning tose
# ----
# iter 7900, loss: 43.394295
# ----
#  ng ba machineler oxul
# mechnidica mppragis pumare mobursh sivachd verratdes thtes for mrlledaltis alaproarkerkeruts chveht rarapbeation
# eethodaticngasion aling
# and anghizama toral apwiber beuled seriti
# ----
# iter 8000, loss: 43.078449
# ----
#  here phou sifivimiza f inc corberorn artsort cogrovedtred ciing learning and machine
# h
# epprer prechs
# heloacha and mppriter detrutigs
# motithm of machin linguasifos ar weth ainicl acleredictining and li
# ----
# iter 8100, loss: 42.852554
# ----
#  earning altal machinel tifion ontation machine lurag corchlu for syporechverfor chpientros th machine loarng rnsiog ledrtetresbiags hepricy mighuus athade machine learnina preinmss
# mathies widal gabia
# ----
# iter 8200, loss: 42.778113
# ----
#  nstratke tom ercleclales
# sideg merilen machine rein teachine learning red tpersionsemative sing rearnic olimg and learning araticys mstre prehnpiofimag lelarins ardicner 6orytas fsofoatieg
# machine lea
# ----
# iter 8300, loss: 42.687701
# ----
#  ont rompured
# machin getific for canf maching wetha wotort crvie urew wulostion beotolic comon onachine learning
# dechin machines torg preficericc machine lies of feath
# sitaclcqurec fima
# fey for fores c
# ----
# iter 8400, loss: 42.728258
# ----
#  mseus
# ans sase tearcegrewimerda edtifiber parmicl beasing and inteckncactio celnarnemanus expipir elaptrry declealey stpalugropubte our machrorithcuricnine
# learning on wigesenviel asedlang dities torf
# ----
# iter 8500, loss: 42.745069
# ----
#  mespimine mechon wita fis th for tinseatnond improrlic and nulorafis dechnich ines fnet learsution arcer d anc ding sedlardizg tore leinergorine s a enetisla al intursidgem tre manpict tor dala learni
# ----
# iter 8600, loss: 42.637074
# ----
#  lcating boy
# mamg digadetrod learine lemad machine learningel foworeh ufsrosiss fointican catabing insise lyyistrerysisl mmocorilg
# alilesmact theund machine learning approd machine pemping dutios sduco
# ----
# iter 8700, loss: 42.605259
# ----
#  iation aaprearn acpinevaed machin of cenducs oation apliation
# momarus vemrostive detrek algeat on micrabent peretpon of for and rfoige machine learning
# mechales manteddas machine learning fiabimatime
# ----
# iter 8800, loss: 42.600033
# ----
#  emlesting machine learning fvics
# sin teachine le com cedithateationtions fory balap of in tork
# appros om momulectoinsina ceamatte of wytha atora
# eppichzate saptorztitle aptiating mangodo od thow a dec
# ----
# iter 8900, loss: 42.479654
# ----
#   fnectrod re furtectind trimank rechcars mputans unsorworses cetilelachuatubr proasifisobicaticathe tetuc ropppras ma shiditative
# wodf ge censions resirsing in debentare f od for tor sestedezy sduth f
# ----
# iter 9000, loss: 42.701697
# ----
#  lmags
# muputy machine learning thodecl machine learning for shemet in thve hemy reticlask peqhialleagplearnibe mepprisetacu for machine lealtine atit axofs apnsiqfabeleles
# ass fection atapgorer
# machine
# ----
# iter 9100, loss: 42.754765
# ----
#  hindipe uncerg diver of lalgacti g eprops
# cuining
# afficarint fa fol archin prederent
# actiof of fouleative
# mathes machine learning sing matangtectifor
# machine learning gramenceres foreh tecend costors
# ----
# iter 9200, loss: 42.825589
# ----
#  f dotew unc s vication for t omal fide sstisk machine learnion carmation ineate preasspame ceand efutits
# utlestion hites
# cwome pustismenen torgation machin pa sith mstos abin seress
# athemela maction
# f
# ----
# iter 9300, loss: 43.043007
# ----
#   angersiva mutamatiexs machine learning reprogsromon machine luarmitalial
# fheary totuus matho witessing forc mactinithy fors
# mantics genithm mintatf angy shpecba wethlp forberoininiar machine loarning
# ----
# iter 9400, loss: 42.945614
# ----
#  hine learning miclingre eppusifices
# d ancanditaly hidunite seagrenmicn op machinel mechine learning on imt d thard caceios of machine puacties for machine learunu lalinglanty on thes machiig oftuwicgo
# ----
# iter 9500, loss: 42.925545
# ----
#   for machine blodevict ths astins detand of of demelos comal dechon cuin dadiramy wing ma and fexlion machine learning of comsiom fos brompricviss mernlantan
# dupratomamedativegle lateveml learning the
# ----
# iter 9600, loss: 42.854727
# ----
#  atining anphe moditicarnase renictimating fsmicnonides yetorunse exntien
# wodsrane learning apurediticegn machine learning dechfod eaching mechin le hinslave mofort tief imats aaple wutymattwo eoplucti
# ----
# iter 9700, loss: 42.685826
# ----
#  orease tercector bor alilgbex machine learning appherzartitical oaltrort ik on thabs in of anap
# forition
# se ghe machine learning aing decenwmin
# ssine ne fonrie ons date ba senioi oamby machine lalang
# ----
# iter 9800, loss: 42.713267
# ----
#  ein machine learninle y for machine learning tunss sing manbaretkr matoinming ticty endofrecting axthen fory anchorew shung deterse fer macininge sremled
# mechning spal
# ann of machine learning for leab
# ----
# iter 9900, loss: 42.621094
# ----
#  ng omlaticapleall acsodars appreriver gent chfigas with heagmifmen gupil foatertpennster os methe thy dowal antsation anand metrodinalastition epptede want ca fororum cactis resurf alg prowf presistin
# ----
# iter 10000, loss: 42.743527
# ----
#  titha furimetind mithos ticnstion tharn fim2tize le stangdas tror brodtry rqtasien appreales
# mastoomtating rearcuon machine learning
# cecting prlol paticelater tormiting
# gron fatidapme anchvem catke te
# ----
# iter 10100, loss: 42.643547
# ----
#  manthrey and wetation spints d pros ebimanaldandiqy anth on machine learning
# percletergesting mantacted coamues
# machine laruins
# mending my ind turmentica learning edctiansysasu gask semsuzing of pupas
# ----
# iter 10200, loss: 42.543934
# ----
#  al ccmach machine sextychniqa and
# aning
# d learning machine learning ata fian scogloethy lianiquellpeperclew in bretwema sting f ow frow rey cork
# cortuen incant for kxporeog comsions a a thatemptros fo
# ----
# iter 10300, loss: 42.682391
# ----
#  ning meton entabtra dotramencesifirn
# cating on arit vives pipark intariquelebses deticle aptiat and learning ba cecture spsiing wytava psbasificcth machine sekansude ac
# athe my tole ardic minbroaened
# ----
# iter 10400, loss: 42.394500
# ----
#  es
# na manmaling beatucont
# leargla machinelearning thont appraad fapinchsy deth comitervina for thr machine learning ppofroatemls
# scoto noabnar mechin machine learnone cocle flem to tores
# cerveid frati
# ----
# iter 10500, loss: 42.069758
# ----
#  acpa tusitive acpertive sing
# arning echostamw untatiofpt and wret datwewive te ertare perlmen cow pirtive
# ress
# ns peremers
# foraleser appnod cacstion astingtion mathver chater machonet
# chrathe machine
# ----
# iter 10600, loss: 41.842554
# ----
#  ithatial
# anmap aplimast
# mote akdiceh antusita plarasiclifiry asperen rehte prod viale coppitional for echagl naterc serottravic
# acthon cornienbermatradast
# achine leating
# mathiqe 1eplalelsien woche thi
# ----
# iter 10700, loss: 41.674457
# ----
#  arning algasiation
# oictore forcemickr shid plodporsion
# 0recslaticion
# machine le reproatuc ang dearcha apptort ma mathon dotithy mechine enchenth hephis andecwith pechlisel tovrer bastorr pprand bay ma
# ----
# iter 10800, loss: 41.579172
# ----
#  cogturasssumin ural cogictrc modionsionl machine learning
# rematord machine learning ufortic aling pring debimemation ryfhicngyvicer detechmemarming an4 c machring
# daty detition artro
# palial antarcite
# ----
# iter 10900, loss: 41.569231
# ----
#  hnindien sufusibe decrtradenemrt thenes
# mechins
# machine hecron gandern aprect mrnatede tarnen inqor
# fo retwre prich
# orore mwcong urtterkimacroca
# fhe varwimase r fer for mejcara mdnoma mathine mlearnin
# ----
# iter 11000, loss: 41.556065
# ----
#  hachien pon chictining foren ifo machine learning npkric indive eutuctic or exytein oaritive tile then aramsieemy
# torers pencoinfui apprimamt amqiol anamptorillencs
# methedproring mallark detupil on dy
# ----
# iter 11100, loss: 41.680062
# ----
#   andicprastion fe mrofticlusbins in dach
# derente sempror machine learning to variction approbets utens randgrac in atfo machon fen gerorica umprecjator machine learning sed actoromts scrace and alullo
# ----
# iter 11200, loss: 41.580108
# ----
#  lictiont mastufiation acth fareess and mecon gesmalpyidite torstie hationcticands arquoret a desursion
# uleglioneltfies mlelening edoferk houmpes machine learcirnicve reatupricloteralegiantiug machon b
# ----
# iter 11300, loss: 41.558538
# ----
#  learning
# dices fo retiteating la dyshective
# ineeingas
# carning waticion
# dadilaricfe aldapbiof bomelturach
# melonicing mathifhectosilge asplicacions
# nelarn alemulution and machine learning
# machine learni
# ----
# iter 11400, loss: 41.449154
# ----
#  hcatifor alealtea
# ustroruri and tines
# for dabe machine learning mechine learning alyoruuumatica machine le foinfunchovect anite appriu machine laledite hiapn in machine learning
# distiatis for in ds
# ac
# ----
# iter 11500, loss: 41.507168
# ----
#  mbormal
# machine learning alal thmicticing get machine learning sef tor conessding ungorcpto dorsexl inthonese flormition machine learning
# learing la learning prode oucions of metertorch
# moquite verve
# ----
# iter 11600, loss: 41.637446
# ----
#  ng
# machine alearoides cyceon menthid to mutyseatiom
# of mechnidiog in aphos revectronatialaliolses mesic senibenma thutustie michal basitizagning on guate forialtus
# atarvere aptiforsus n intorthehc min
# ----
# iter 11700, loss: 41.688802
# ----
#  n athang thvie ox mexkleut of melranasition to torterention aprofregecsy foules somissyten ticty in a sed fos inttaring mgannphew ianquetroks in musiman asfirserd finite leral epuc didort s anmack tho
# ----
# iter 11800, loss: 41.847479
# ----
#  sd methmacaseeniqe thel goramtave plare of tanky mplialini learning ba bded besifing mentaric omthew
# st thons mathiod and machine learning
# aat machine learnifs
# of cef oftiting
# machineleanc ing machine
# ----
# iter 11900, loss: 42.021250
# ----
#  arning tert mechsof mith owsifidion mbarizi a machine
# loresifion learning malal urceabestrasdidy
# retasition matarjhs moqearmardd
# machine learning approsyoden
# crokyty application appilstes fom6 and ma
# ----
# iter 12000, loss: 41.928996
# ----
#  echtine lolalterces for natolentis fis foarkericlt appromagficsbet apliagid oferenudim trectioves for the mplarkiczizactol va groarvey tarnimasifielingy mesutrest urengrulpimagantem masding arnsiing m
# ----
# iter 12100, loss: 41.948386
# ----
#  dytrach towition aphvion mathioweme groclal detac andy wocuction udsuscacngoltian machine learning mathow of and vict rea of spwrrama exviseratticytiog furunmarg onention amploaclitien altatedutes for
# ----
# iter 12200, loss: 41.907797
# ----
#  ann for ank fith epplorizapet
# escty for faamabnic machine learning
# pfogwomtation
# inves o4 lane fests mpreuticy of sitienmits westues in tolarisifice wazmwigr acbrfore susted cibiod machine learning as
# ----
# iter 12300, loss: 41.786151
# ----
#   learning machine learning and onk oachutl learning ansusprosies tor ands rapliugmacting mforeditication and cechatica for pancon tba gatime andy fur to eupects elenand cofet inmatis inuledic ad aczao
# ----
# iter 12400, loss: 41.697863
# ----
#  zal angles foata teching aplicqlionstion ba machinelga prontacpo bnedborpel vare reskarusestere ralalins gvor machine atalstulec machine
# areack fore methem broacne senks reppection
# reas in brow
# thve o
# ----
# iter 12500, loss: 41.741292
# ----
#   learnumappersensturata tex seforent machine learning umagimatecbrel parce pnog tacsing machine learning macprouus mactinape thonstwiction anf inthratimasb ditecting nemltact
# dema nenpos
# machine la ar
# ----
# iter 12600, loss: 41.762473
# ----
#  acsin leacn liaring ines
# dagnistiens
# athe axsizag id machine learing ratective mrtaless
# altorm appracongegs machine lealtion
# uopseract
# d machine metoins le machinesrof machine learningers
# datamtomsion
# ----
# iter 12700, loss: 41.718228
# ----
#  vemwemels codsie learning stannevalasde for mechy theturank usedsitimr sews
# merficaty a dy
# magal lathorbe rederoidetech sh puctrecsy foristes od diths furionsing bal ons
# maching
# dathe maching leverute
# ----
# iter 12800, loss: 41.703255
# ----
#  rea machine learmor to ra ang stuvecsing on acher clontion dearn eprogumatica fis reperits
# quacticn
# learning fors wites poploans rasturn torlation sede spproquonelste oftubase phnargorituriza ansieple
# ----
# iter 12900, loss: 41.790976
# ----
#   ne macompt of tiresca
# medoris uren cautort mantial machine learning acalil in gnasting annebgial machine
# learning
# fuless machine learninga and untermalsifivas hoceced utromsy uwont inoltyation in of
# ----
# iter 13000, loss: 41.454858
# ----
#  y reand lybrodutation
# dalele scqiogrelmection of s fer algor for fer machine la ar machine learning
# machine learnin vechvicaticg aremaluessls rxaba apsing lewetar
# sumeltore sinap learning altand tacti
# ----
# iter 13100, loss: 41.187579
# ----
#  t
# techsing saprizast s machine learning ternglith fop of incss usyasiing and appibice tor mgysmal methitatation
# opesion algachevimacnizating ba machine learning stare poolsesmomes for s atpvecon ar fi
# ----
# iter 13200, loss: 40.880340
# ----
#  and baocilide perncation asppvresinicngrve pricht for s for gene hoal blive preg spenticper mocinic dape prods ceccqoetre mo ectogle of foarl saspiongassy toa thmal coplogrectouveabpers inth erlalun l
# ----
# iter 13300, loss: 40.793826
# ----
#  oat asimwalgomatle fors
# machinelleathing astores
# arcealasilg
# bearfrorictive appatarautwimucpion apptive michodowictre machinen learning
# muvry machine learning dytheastrod onictite ulad for in inste le
# ----
# iter 13400, loss: 40.701139
# ----
#  terecrine cand lianinitioncarya bore inoantivationdar hylemet pres acerithy s machi g and aus chenation of ausiol veark fatroctocle rebiofgwal for
# ngarnifre sing bamel upichin for epppreark msomamosti
# ----
# iter 13500, loss: 40.708245
# ----
#  ng and inzised thactine learning mewoiniemlt seadtation
# ancornbroalitibe teation udedeneny egrariclals stteat net
# retert dstrod ms ancorde mphorion anf freh s
# sqratiale ursbe tunfector
# 0uptr fors
# mach
# ----
# iter 13600, loss: 40.672087
# ----
#  imgleatnine proaniquoachine learning balmalsy foretion in mation
# aleaniblearnines and scalgral dapring liqursuros
# mectork tororegiog towy stdemition a mechind machine a anato dedel manting anmingloagn
# ----
# iter 13700, loss: 40.847940
# ----
#  earning incosicolterodatuation insed cits
# sing and uncionceding soiney plaapilent bfemations pach petorcysition sudomle in anp of textistonyted machine learninglion forturdic indens fod mumotiot
# cans
# ----
# iter 13800, loss: 40.736342
# ----
#  ctiing bromatecection ralgy
# mete faretretras machine learning apprie cosisilal odtex bredatiting seterions
# machine ing andaltha machine learning of sofles dytawes sberserting
# dedisfive atetemas fho pr
# ----
# iter 13900, loss: 40.719063
# ----
#  lescion binemachind entarclal boppring ustionique s lewp machine textoriqma stins techine oubpisibamacacing witecrod machinge s dade machine learningsificarfiscewice menas qexamforne aing s d afnonchi
# ----
# iter 14000, loss: 40.583195
# ----
#  lecichg matrize stimic senssins s serimele raperabe and mrogreadlicg hupumrithod machine seviclog chos
# d cabnic widaborvergy edelet sifipistredt
# fointtutuant of cryysing expethatation
# boptorpides of m
# ----
# iter 14100, loss: 40.718216
# ----
#  ata spelses machine learng mofork pemoation sumatik s sid pooupeb leslection fne machinen soprod in coguytic machine learningleastizaching machine learning
# machine learning mechcionsion machine learni
# ----
# iter 14200, loss: 40.835318
# ----
#  anizecection belt d tanaterk torere bistras and to igeme booutipe machine learning
# acters
# adosepac seprodipnse machine learning sipest maching tengestha dotormicst learning monsefumandiza
# neipisiove s
# ----
# iter 14300, loss: 40.907273
# ----
#  icer machrad focstical alganumi on woms acthibulitin2 fnaritations thomgicngas darlastite seactwark of gatis cosogpy balitest machine learning od teomes aspprorale asdverorogret y achedvivatine laagne
# ----
# iter 14400, loss: 41.163040
# ----
#  aledet seltret tede iopraged for an leb orecoitands
# a sectunt prann anvicorne
# muckelting
# mach ofrerippers uwens for bine palionta ing on tho bichorableet ive sefftive texh rod machine learning learnie
# ----
# iter 14500, loss: 41.202028
# ----
#  quhoptwow foc
# machine learning for uttize tricld sersions for co procpureal asper breviacting uregringred learning sumalaty
# machine learning adpwalticatics
# machine learning rateamuta ands
# acerks shaly
# ----
# iter 14600, loss: 41.236264
# ----
#  alalenidiclsing of thoxty untork machine lelanivems anttroach of frmag machlies
# for and banniclarnile machine learning bopolticnmeters catigfet ymursulst ayme osmotle torwo laterthes
# proacromardicanin
# ----
# iter 14700, loss: 41.221826
# ----
#  emor machine learning pred of mincewt ry tornderpordasl cemseliod eschuvistion texst fing
# mecthin morun machine learning algos prodes ons
# ands of ditechmal incosting ayclestiing aspepwor berarturib na
# ----
# iter 14800, loss: 41.116159
# ----
#  earning liodgary tacficaning
# eneteric od matarmactestrasize learning of bin disba ates demank mathod chine scvenastien ang s mproateation intatione apleart oachine learning inmilgomariont minte ky mml
# ----
# iter 14900, loss: 41.060815
# ----
#  iipuls
# plincomqvi machine liapiced hizects sedme sedtroadeds
# drarkeachne skeation anthas
# machine learningione raplemerctualsionecsions
# machcares micting made inturalape gruukuonedicugor precrones
# y sc
# ----
# iter 15000, loss: 40.965177
# ----
#  tras dechontioncedutrons fo scorperormacoing daldication l4brosery d mettine tenedration
# of algeomsubiction machine learning fom
# oa prebforc chys
# materinic asing modomomic machiforissipre sinias on ar
# ----
# iter 15100, loss: 41.021635
# ----
#  machine learning asddenshon axsimannieg
# apriqe athing ulsion and prod thontic dagr intaret inpogl
# aling fo odloach
# codicsine learn aydimitalban ansfistore datifum talales anthrutume machine leagning i
# ----
# iter 15200, loss: 41.123352
# ----
#  mplemacion machine learning asten ienumeret ovetre metert phestic ry stetidas pomaresy macth a for geniknbpes furmikseation algor and deation alagive intion
# machine learning and acorpwary and terrorgo
# ----
# iter 15300, loss: 41.005548
# ----
#   fort gow cofle mewitiing umadper inter mptarsus
# eachine la thing atherisssugnonithn coibemttesty achreguaticain
# ex bifces angrerogle machine
# le oppfeverco arenoctes of thro reiquation
# rates
# os loachi
# ----
# iter 15400, loss: 40.959733
# ----
#  luinen machine learning fidicngew sepeties fies anceation umelse for machine lialg gemen sumforct bies lidited machine learningza enthapisspo machine rectiton machenimiclilare astare ndinghe kenerissb
# ----
# iter 15500, loss: 41.205940
# ----
#   hehs auls
# frem ureds
# reape ture machino learning reid chation in in foreme cjetorserual dindiateation
# sedest ex ysplestion wipgrod fornde fas
# ewcer learning andyl and sid magnize sprico in und lianct
# ----
# iter 15600, loss: 40.800662
# ----
#  mocenbes
# astiog gevive machine learning soinsion ama and machine learning witation ofsrodiclsting tnadel textem of porlical machine rearcomreals latgreves on the metenthre machine aphemete usovec for
# ----
# iter 15700, loss: 40.490415
# ----
#  learning of
# gust of ceaclimenenc in ducpiomsion foarkigeel undictive ang cegnic of thrse in learning sco thom verecth
# quidegworthew develtt for inus of approeg ofs
# machine learning arde ve lewrytowic
# ----
# iter 15800, loss: 40.189248
# ----
#  ltubew chicting ulterk
# singapper oach mechion
# sasion sesionlea fne exullases
# machine learning
# machine learnmal
# ayng or anals learliene in tagfates
# septery
# alallestion
# achifial apprimater machine learn
# ----
# iter 15900, loss: 40.092996
# ----
#  r chiming learning learning tection aplition datames for
# calsis and in machine learning foactis bulitifion semuporastion
# forcov withch masing phoforestorictarcesenetion
# machine learning and prok kofor
# ----
# iter 16000, loss: 39.993719
# ----
#   scorgeworneracanifone machine learning fo machine learning of machifeicstis peckimationters
# chasime seduseforkarh
# machine learnifn cylastion cogrogieuthe nivireg
# of tha stow
# alaclorniog
# then machine
# ----
# iter 16100, loss: 40.029690
# ----
#  s
# mectronvices in appreors ine catiing tnels ang mathidigente asnocsysif learning machine learning preasting
# wy ikey cexty mgorst ratecytion
# machine learning
# autocord precechin fe tent of adou tearnin
# ----
# iter 16200, loss: 40.056083
# ----
#  vice edliog uwechging
# fapple osimal urcoftolenstien for mechive mforecbpe anpwe roclice getomebregial and efr machine leating dach aspark maprcorying mianditisibalaratac ou tearning
# quromatientoros
# pr
# ----
# iter 16300, loss: 40.247721
# ----
#  arning
# ang onorection uning moquex cearning ma fory sictiod meltalgienseveat
# codfichred veinugis acos machine learning
# trogsy machine learning of viof
# aning
# meutive frection bplered and appric cemosie
# ----
# iter 16400, loss: 40.123385
# ----
#  erus ul for thoxfuret necrid learning aring machine learning
# mechine t3picsse mpracciontrede altarg metemetaction detakse thes machine learning to poa starchs scopy wesing or the cac in toach
# fore bav
# ----
# iter 16500, loss: 40.071851
# ----
#  ine learning aun of texteming s matappors scons vinteg senmation
# sicith sinc sing of ses extictomr alaline aysbeqjicl in cods for prod of codicnmationeh appics
# machine ns
# atoidition and casteractei li
# ----
# iter 16600, loss: 39.920206
# ----
#  micasting altles
# steducten ancwrarnennsive tectine l astiod ma mationles pronlent s machine le reviotes machine learning rassifo na mplarkure ofx pe maching apploatalal of prosith mofpoling sonserppie
# ----
# iter 16700, loss: 40.105339
# ----
#  s intrit gautros sian domapisting rescfig machine learn reltegre in ratfoumltupreceratema eysinge recolsine relaringes iv moastelop surefs
# ulg sithabe pheckificine liarn ang fil saticemizinine resyute
# ----
# iter 16800, loss: 40.279659
# ----
#  phocunftmalticappies
# for ans promaritewealtiofordizapper scas
# thes
# s od cos shfor eychras imet loamersbor machine learning inmalsion preche eleac matorinction alsinasial usting bis for oy fhe mathorin
# ----
# iter 16900, loss: 40.304960
# ----
#  g
# suprectia terachnet rearseulbates ove machine learning
# sa trowler rasiva
# mendial uscombod cacal antwoarest maca ne relpilwarem sppoid machine learning and machine learning
# bult
# manwers
# dal alelarfud
# ----
# iter 17000, loss: 40.551803
# ----
#   lang choduhtimelumibens to mpation
# learning fortution
# thation apepiowy araskinulartal aphiofatialehbyvicter romeleal and mobwr praty acal toar e dppacfi extropoces mathor learning tearning rithoneted
# ----
# iter 17100, loss: 40.594696
# ----
#  fietervicabysesifion and desytalle farizapn muching tomtroms
# d slesswicticl wing and machine learning tha bpreodletuins on and machine learning viafros of machine learning
# hyiquforurome mathom mppreac
# ----
# iter 17200, loss: 40.596339
# ----
#  iquralasing petection thed balt tomtornexia ons alalumate cepapes
# dchrateranation ine cecthe scas ropotard aspron detatiation senicticaleny approsty coggratation aca of and ve maching
# macting meccansi
# ----
# iter 17300, loss: 40.578698
# ----
#  ion manaine anpbrosicore percsune meconds
# and 6ect for machiof proccegrandulyss to made toltion leagning machine learning
# for spb alal trodppeimatuinoliaticiten pledst rebalistican for ssiformic on mo
# ----
# iter 17400, loss: 40.550985
# ----
#  ial selowuatal
# diclanglastine learning fformizr pofme cal gonc a machinele procoroution for machine learning beasbuopfechmagiongois of ipppic and for loaching of cuick fiod masmil legrearnt to s machi
# ----
# iter 17500, loss: 40.461981
# ----
#  istassise of of repracation
# gnas
# dubromis in machine learning and machine learning machine learning in phompericstore netrest metection retlucoine fy wulution bess ratigor data wiction yetergor puttal
# ----
# iter 17600, loss: 40.407748
# ----
#  iagnsuldiza in ofpt autelinal welathts machine learning vanelsion trratimation andatios
# for varion
# dytamebtes blt mechrepecamaling sictwe iny opts enacivass
# g machine learning appalaction
# bato
# protitw
# ----
# iter 17700, loss: 40.455288
# ----
#  ng pelengoitatifos of sive b rad od buplation ar eutraimalec redialcoring
# skimling usenutwarusetumimes
# manatives
# methredis fororocieformial on chraration fienmilar ppomledsifion onucorofechs forurich
# ----
# iter 17800, loss: 40.497757
# ----
#   of prrugke inang macton mod machine laline on lechon and on thon liarnizappryationt
# crifhe placane nithomenenceus
# machine leanning orotes alodeacitasiciont
# machiler werem machine learning
# bristion ma
# ----
# iter 17900, loss: 40.426639
# ----
#  sers machine learning dotaces torary ofetitective te antyt inse th fre mgaring appraek fkromite feratfom ex lar learning
# maxprofetie inelngativa
# msitenmgrok
# machine learning machineprearnipasime achin
# ----
# iter 18000, loss: 40.397637
# ----
#  g alegor for shplion in
# ch torloming and keching s3ugcates prefiom seletation
# resoncstion boating anale forvisudid ins fore sspranse ppargie mathare towrod neblogal
# corgeva epplorbty wave att puopolor
# ----
# iter 18100, loss: 40.617250
# ----
#   learning alturk machine learning ater da learning
# machine learning
# machine learning sprofo netw thary byuct
# matmatkes
# ral mencations
# machine lialine learnipic section auproms for int machine learning
# ----
# iter 18200, loss: 40.145138
# ----
#   oachon andize codsion setrertes
# miclatylalyties foack mechynteming reducmics fiod ines ippqialelalion indeclsew brodicsing machine learninge and probs
# fyandy anditesing andunt calaulions stmorte sers
# ----
# iter 18300, loss: 39.916580
# ----
#  arning asticsers
# machine learning for of emproind machine learning
# fer
# onomppromsivicestion learning detectix appling resuslst
# detmagperning and pwitet inewrorsing atsitur ousing aprleutes
# napa machin
# ----
# iter 18400, loss: 39.722511
# ----
#  ing alalulame machine plearninierinizaching tors trarforyted ins desing thet learning
# 1macse preser n cors prod ghewedrictecbime corct prontared saspers
# machine learning sectes machine line on intacif
# ----
# iter 18500, loss: 39.586054
# ----
#  altine a mprodasing qeranitine peptertatorith mipraporkicacn wate tootiing approde tretuczarp mescersecton sungeagt inem learing forodurt gerection asproowort exs roultationcedics fo soindine thos app
# ----
# iter 18600, loss: 39.449592
# ----
#  mitatins asprocelt
# vy grimew
# arnilgic oftewive techmanumtic ther machine learning comsed chimencys
# dilgare anmase for gingor aldariton oach
# proag machine learning emgls mipgemitima mathe
# liancpan appr
# ----
# iter 18700, loss: 39.566979
# ----
#  ns
# d tercple machine liegrimertegre s machine learning attea pettork sheme machine learning wompliclgy ha mutiatis dider toce dene tistor cedfcuan evesymady to masulged textrasting machynesnfira nesic
# ----
# iter 18800, loss: 39.453110
# ----
#  ine litala matlicetiviza desing ang aling feras machine learning of shakd stors babrek aene and and gesediclluing lazaclle cecting ramow
# opolasing tucpelk oy maching auscs achid en uantes dade kewechn
# ----
# iter 18900, loss: 39.696901
# ----
#  tion
# ereloise adision acantures fem ting ox wetingy for expploraysima nutocion toms for mralnitank ceurocowing for scongy
# gy forde armeliap sofem shemuts apprix wibation sith nimseristic in proxtemece
# ----
# iter 19000, loss: 39.527074
# ----
#  and miching penon varcew uritigan for fros costical mathiduwimeting flacsting matheuticol applizala focticy machine
# learning
# alstista ind eurgive insion toctrasting of dalgationveal agna madenteb a ma
# ----
# iter 19100, loss: 39.528996
# ----
#  ertarmaction ansear id machinelien ge olt
# diandigl
# se momels dites mobunk machine learning to tronronifion syse eptiration
# machine liagning atuby frot to marmictive metaltatinses in wes algorimse nain
# ----
# iter 19200, loss: 39.417685
# ----
#  ivinastir
# machine learniqy
# actime learning
# dig seblsigus iny sensifion applomalyzmec loblarve techinelyation of mationsoristing litwatex to mecroncte ssutens foa predith
# oppro machine learning conser
# ----
# iter 19300, loss: 39.606758
# ----
#  csleotores sfogtured lamagestme machine le ethimen mechine learning the prealarualk maching phecradion fore machine learning
# ta oy detrod machine ershedect
# tte ercifien learning tomation hoppididion u
# ----
# iter 19400, loss: 39.796523
# ----
#  earning proulogt sematicalalealtion actane mphoadeys
# uservien of vecwive machine learning le styving foressula sededictive adarfie to ctection in andetoind omefislw machine learning fororion bache tha
# ----
# iter 19500, loss: 39.790051
# ----
#   apmot andy inulatatus
# outupaticamly onitis paplecting datpres ang asfne melani and camesry dojertr ofs foast machine learning for mathind wing basuscere meching a machine learning fo atron aserseptro
# ----
# iter 19600, loss: 39.988896
# ----
#  ank bintwrarstne beswary stapicture of sumisimations forer epimoforme ter mrliofurrogss in mosestebntey gecrateration coactive s4uto serphimamemal calaned d recatenmibs netweril debrictine inty fh mac
# ----
# iter 19700, loss: 40.035638
# ----
#  d soteic atugim learning anners wichunvabremttracwing acpatication
# a of webl
# inod for the titems of fwem machine learninglio cofionss machine learning
# machine learning and scride statyticng and intabd
# ----
# iter 19800, loss: 40.151848
# ----
#
# thecting buviel esubt cor inkilallestion for alegle svrom machine learning machine learning
# ...
# ----
# iter 105700, loss: 34.768875
# ----
#  s of sicldiksion
# machine learning resedistimatrasfion methvective learning womal accige algorithde phagasp wagn retf bloworcogs on clesing mathc paract techniqlesc
# mulsitation and sonfirasion appuenge
# ----
# iter 105800, loss: 34.654477
# ----
#  strywiss derces for shyumic machine learning approseark ivapece inthmabeal equotavety untrstemm desectic ending minsusl fhe mrarnirateut a learning
# machine learning a machine learning
# machine learning
# ----
# iter 105900, loss: 34.640586
# ----
#  s
# sutfic learninger a carisnfeitfixs oy intem stan ryenogization scext quank based prots anduscalinaln monsi learnignicess
# alegentegring algorl gesededencels data cpref ehcation and comd madios
# machin
# ----
# iter 106000, loss: 34.847434
# ----
#  fur sowyrd techniques and machine learning
# contutications
# pac 2d appare ang machine learning anvic lobids for use now eadnognyriresion machine learning attermics ussin machine learning extralt bam rem
# ----
# iter 106100, loss: 34.509605
# ----
#   suul predechon ditatio leata fnation al reperin coveara clatieg for copimantenc
# machine learning henocion clernicic syssing
# welwationgee mannory the text learning ad fvimige ne malabiads rotar machin
# ----
# iter 106200, loss: 34.290553
# ----
#  used sectice latinal gentus
# learning ascodin twart ploation centic chent
# matelionsigad recemele extradluces
# omr nistro daly adsoman dotnizatnory to real in apprayse uspales dytecation somverimen te so
# ----
# iter 106300, loss: 34.009015
# ----
#  nesiforatura
# mino sualy deresesio machine learning
# contunt compigternicasiting tostrary bancr comppatiss preagk of skicareasticens
# o4 learning accis a micprials erpoias
# inlels reant atiupele sorpegram
# ----
# iter 106400, loss: 33.862285
# ----
#  ersture actan a machine learning apqoles databispphem a methods o machine learning methoquroconmationing robructing
# machine learning approatnearning approring gericl and detecting a precoinfor machine
# ----
# iter 106500, loss: 33.707185
# ----
#  machine learning of for singrizy
# machine learning
# desegoced revare bactivg
# machine learning for vibets woctios staristiof epprresions depexficss propgarves feritextw dachine practic anainity deptind o
# ----
# iter 106600, loss: 33.707049
# ----
#  gralle inoris dutimaticasity andenation tha deatorize
# uset palce debtions with mphracation apprrian mathorse furel machine learning motacer flal of intrals for verpordach marasion
# zarmisul dend detuct
# ----
# iter 106700, loss: 33.748936
# ----
#  er edusing ik appcuativic in approades fouthmabsk cecte algorerw ba
# machine learning acasifications
# modest wo of ernognition
# maagnionling mataractuon dericlsisfe and datas didtrach verigramimad dibgor
# ----
# iter 106800, loss: 33.925440
# ----
#  sbing machine learning
# rotechn anchusion coforyses for scarist praty frodibinal aseulturas in machine infistets
# mignontation
# machine learning
# viowl debridate methods
# modext
# to sebsul fy eninfory thmsm
# ----
# iter 106900, loss: 33.879494
# ----
#  a machine learning
# mutied texhjy daticty to machine learning
# dgopleanch profhrichlbejuct tresed asprearn anmlbassears for concisesting methicasication arne machine learning and rysersels learning cali
# ----
# iter 107000, loss: 33.831806
# ----
#  ialset in dower machine learniny of coms
# tonssimabial muttiticigassing chan machine learningation of machine learning and scartales anc vire stodyd te tint opytures
# infork melonterative prausion andes
# ----
# iter 107100, loss: 33.730859
# ----
#  lores and beuentbasy and streyh aumpmbeiticast preducticasting tearfom bsiver detective
# ambrasseve edifeme scape atyts tod of mviol learning rime pasanmatel scoss with exed of machine learning frant a
# ----
# iter 107200, loss: 33.866228
# ----
#  ns
# domporen scalt in blig premadowed cugiuinotemats
# stompigming the soltatition gnelalengte per banathe usenetiman preditulidatection on sine domplerumicer alghears
# methimiss a clas lealnengic bist fa
# ----
# iter 107300, loss: 33.997943
# ----
#  as
# vector a somcisse machine learning
# machine learning
# oussbuniten machine learning a ideg cyvex supasition applical bletysy the machine learning and frard for devene geastimaclalsy aynse spolenorulsy
# ----
# iter 107400, loss: 34.160953
# ----
#  l ppprowied chemales recemnollinitinenle m2chinas for machine learning machine learning wech
# ancre sugrifical sy mettifes of parming ty efarperocusion to shorits in machine learning and pricerensal en
# ----
# iter 107500, loss: 34.398176
# ----
#  ine learning and recogcer sofecing mmingig abisspsic approachese in malilary
# ext reidurlation and mistidgom machine learning and for pran and thekter progric intern a dys approusleworms
# machine learni
# ----
# iter 107600, loss: 34.509856
# ----
#  rnes fied cury
# prediction blications in machine learning
# acal a milary varnity machine
# s
# pregrordic the baseins sclacfic carfication approach
# cosstical the machine learnine
# larged cane bayl devriser w
# ----
# iter 107700, loss: 34.488337
# ----
#  unmambel foon machinelearning of simical delttemy quet frod alal sifnasification
# machine learning for machine learning
# procting mactions
# macrine on
# h methodpturationication genadparast diquhnenonterve
# ----
# iter 107800, loss: 34.587919
# ----
#  gabolen maching aling fractinvy to femo in machine learning analys wate gandine trakendasebpen twark nebimante joopumells
# parategrore for ranyupent for scamipleds activi learning
# mraling indes vyecmen
# ----
# iter 107900, loss: 34.637255
# ----
#  g for vucutabarealing appina mecensppuratrime a hinarie owetation
# priibrard machine learning dearc scancy interic scpan gan atorctectines
# bresulity natumizatioregatore machine learning actaning dintrs
# ----
# iter 108000, loss: 34.486066
# ----
#  eleystor hid micoumeliterbabsousnication sed fe
# machvreht meteseropicbased shection sectied lecrimal modotice ensbratorilass op axtorss spinables on machine learning machine learning a st oretoctory a
# ----
# iter 108100, loss: 34.540115
# ----
#  ng inthatic achies of mithods
# dita sente coctine la foe craodilaly a nethven thing techine learning adsydan rasepurceds
# a monignezation of conic in machinelased for bofemminss flangy foet
# peats inverb
# ----
# iter 108200, loss: 34.586433
# ----
#  slig mata anky modutew
# chification machine learning leapnitytring machinequvine scoctim tregritivr hyssurtused pregoem machinen
# sesiy antersomx 1hergnifical erpood ardection fiof engapases
# datucar ald
# ----
# iter 108300, loss: 34.721740
# ----
#  icals to mome exersentaborical applicationactine paration and clytes
# machine learning of ar benuditer oppuntenit senuasion for epaltt actati lestin machine learning
# jufomas overutowicfinises fre brapk
# ----
# iter 108400, loss: 34.568841
# ----
#   la goonsusis a
# machine learning approiphet cank
# d eacaot sspimancorithmation on nerations
# and compurfibolyster midnornion learning and parwastivice prodecive smats echouticasusing prame feictiing arc
# ----
# iter 108500, loss: 34.505200
# ----
#  pact perchenme comiclasions
# mithoxpbre urontal par and for agnpamp for enares and gnsecul networkits
# rpaction and machine learning ermasticas with encold pomsing pregective machine learning phedvice l
# ----
# iter 108600, loss: 34.809009
# ----
#  hine learning using detaly machine learning ussing renc for machine learning prontsting phresies and and bretys tromaction
# hotective la gnining segmuslie boled vrall gen atigcor machine learning as pr
# ----
# iter 108700, loss: 34.419618
# ----
#   methon tho caticste and machine learning
# method ussbepurc action sobfys
# olemlier skamputh a comssipns using sudics in sparch machine learning approachesbassiving pepwitil algore bgody machine learnin
# ----
# iter 108800, loss: 34.234652
# ----
#   frmics
# mevem learning machine learning
# machive learning trches
# machine learning coche ascoin learning resediscation of heholiquote ternala learning
# schmal gppoated of supimagious abarmercicad machine
# ----
# iter 108900, loss: 33.926164
# ----
#  ne learning sums
# compromparm and oppain quocing machine learning stasicased applied a mictoinetuction
# intitivich the prarional learning quantisse paxtw vietmaturan
# applientiog alcoring prusionstimal c
# ----
# iter 109000, loss: 33.757015
# ----
#  celsar and detemifil leterfy onette extrabation
# meclliar imporing of interchinan olequetrual scode sctithviol menfoming for heceations a ushing plegatoinsutares a somulabss a fy useblic realforition m
# ----
# iter 109100, loss: 33.634642
# ----
#  actiod learning
# and ture revictes
# motecting basesification mection
# machine leigysition and ol detection and vinetegretece dyssincerution
# cull kingerochtuve intors a machine for corn ternogipiter conti
# ----
# iter 109200, loss: 33.718548
# ----
#  er mathimental siction redeypal ix co sedum
# s detection for intervatal a micrasssis in vilal in motion a mector conterne precfition of machine learning leaptrastine to elentoritica in introdution algl
# ----
# iter 109300, loss: 33.699009
# ----
#  pricst on amalhne the predich poaperenova machine learning eminanp for machine pepolicatien netarces the inderallining
# machine
# lied anjeurmal phcesourk elcarna g powamp detectim a machine loalls
# gefus
# ----
# iter 109400, loss: 33.965438
# ----
#  ng
# machine learning algoricting basion thes prediction for rigybelas upproach terth machine learning
# diccalatyxbopel ceremutoric sobancperveationtring on a approach usal plogernanfencedion machine lea
# ----
# iter 109500, loss: 33.827159
# ----
#  ing astromared in o liagne exar molemipatedel ontale machine learning for machine learning rearced to texh learning algoremss me protomal procon glent machine learning
# machine learning machine learnin
# ----
# iter 109600, loss: 33.760352
# ----
#  uincetivi learning for anal apaparcver
# dutiver mapproassher in ploach
# and bliagtic to migntes for broactilr and sedionsus uspapizignseins for intruic and tranes
# dytucidestion epplaves for approach
# a b
# ----
# iter 109700, loss: 33.672761
# ----
#
# eppcimicfications for phrodsovisive machine learning
# machinelestrare privilial an elval
# osedicapled and chabs a susssting and intreds
# coval bopidesho we cameutiva methoation and nefall combil foate p
# ----
# iter 109800, loss: 33.835218
# ----
#  ts soptre anaundate fury precurve learning and blarey rotsed data ext hepurtical fhracks usseding sugnesstorieds using ct and the cfoach in machine learning comapatien intermd spurithm adsver adolial
# ----
# iter 109900, loss: 34.035799
# ----
#  re in of falctectred dupticent learning
# reactic idpleatfor to for lite coltranes in prmaling the classifical insa machine learning
# palovarsst classies for moble semet metegreal olesolsh
# machine learni
# ----
# iter 110000, loss: 34.090237
# ----
#  ine learning of machine learning
# anghs detistive scom apianmatatie learning melroasitive sinme inar on sumpurdes
# plearpemen momplication soncerus mark rargory siforing polstbasedure s auntroonseda
# mac
# ----
# iter 110100, loss: 34.266131
# ----
#  alalal sciulustination
# proderling the methowe polechow
# ne monssion reylufodegrenoch
# machine learning alantesthmann dateractival spacient leamecion in ty mew capal and s0fh the pereslemizal weustor tom
# ----
# iter 110200, loss: 34.435324
# ----
#   towt senar with wy moancare thoning active lingins dutection
# michousitiosy dethods of ergosses to kypa
# machine learning for blarpuls baytions matrotex mrerig machine learning se sedicarity with esure
# ----
# iter 110300, loss: 34.432523
# ----
#  ts
# diblecllesting baytion for compuld machine learning proricticablassion to and dutag machine learning minalicaapply learning machine learning of in spopissification
# huditere images of machine learni
# ----
# iter 110400, loss: 34.486251
# ----
#  ffo pament introtes stunation
# in dent machine learning bimation
# motet atiste inkegro lighs broft data machine learning
# clal nebpistaleduriss frobul gerizind rgmiust ning in machine learning as a preac
# ----
# iter 110500, loss: 34.553294
# ----
#  t machine learning ana wanding sithmstomentsting helucation on elearmaturase parallet didices
# a spumemturing to selwars
# thomutser frmet for planoutter machine learning the latectic redechch sustred ek
# ----
# iter 110600, loss: 34.462734
# ----
#  g nemm of mofos
# hopples sinonfors
# pindissive formation
# machinelicate a fruaining trassifice in and approac
# d sedrvedworple asinabjemact
# machine learning reveators
# tenfor and machine memiclassification
# ----
# iter 110700, loss: 34.443515
# ----
#  ne lesing hil new aplyncer methods and machine arnardines
# msctied approache the gloulve of for moborial reprasaties of and sparadive learning in machine learning applization of cainsederveroctiol inte
# ----
# iter 110800, loss: 34.549005
# ----
#  arning autiof the dookutating tranes
# antery bining manapegemzura magpeins vact and wmarchmetrade od cons mext learning machine learning machine seathim learning
# watatec canfernsists pactications
# of po
# ----
# iter 110900, loss: 34.578829
# ----
#  n
# ol
# hecans
# amgesy dar of frabies for ribas tranme iangeses for fe aiths
# ta seary biehteds of wowcen copictice methods
# elearshasition of machine learning asbromels
# combilentatications syeoxpewoch nese
# ----
# iter 111000, loss: 34.492466
# ----
#  echniques applowitume helene intercorserdind hiantenctic and proctissedviza
# sconsopilatestore machine learning of of machine learning machine leagning of quos learning techniques for poogistendet tha
# ----
# iter 111100, loss: 34.445645
# ----
#  gssion at wersew machine learning anfolase datach adbofyusis
# a alame seted and igelesers fromant tover fured on hicontedse machine learning for caltige
# gevoratiig dutemins ofleforte claslites vinogrsh
# ----
# iter 111200, loss: 34.722547
# ----
#  w eted migocerd lyaglection
# machine sa
# tuaral metuapatises
# previstes aty dadulensture to dene coct prance machine learning
# machine learning with pranclites and rapes ulesine fhenveal
# meteral vearfic m
# ----
# iter 111300, loss: 34.294869
# ----
#  learning
# machine learning and wmaton baicticess wime machine learning iroloultse mpracc fraclder viala for ang fouse atule actora machine loaching of ditadal in uptiatiusescicn
# gnsletalt machine learn
# ----
# iter 111400, loss: 34.102603
# ----
#  r machine
# verimimal desedintet in for machine learning
# and dear derning paranckine
# sofe learning for scog dage leatnoning and accanuslen dougor in onarbils detonn learning and indic in for athoction l
# ----
# iter 111500, loss: 33.916697
# ----
#  f actication machine learning in endertuedicas in using in moblorkilenturask elearnization
# twarks
# canams devat coopg a pactestimatrotsificy fors learnigy pronation of imotion and tearifine traftations
# ----
# iter 111600, loss: 33.701595
# ----
#  ne learning
# in machine learcing stal learning news seate bleturkizic machine learning of procyndaring the proxadeoric
# new lorplivisces
# metrods
# aruntitis planitive mo learning frorkatiog approsied sta
# ----
# iter 111700, loss: 33.573679
# ----
#  anjiong algorpal intracper ins statrectiven muttl elalal and binenussifich ovistins using provie fobiod attramizantily shegeclanal hy machine learning balser clodillar intato chods
# destin intetrewomus
# ----
# iter 111800, loss: 33.693775
# ----
#  machine learning mathine gupuinimg hezimizitan peult learning
# doterth detach
# weng to andrime
# the many pactem
# machine learning asqforc
# sumast
# cotition and using dethe state algormicitatfor rang chopilo
# ----
# iter 111900, loss: 33.613680
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-4786ea18ee23> in <module>()
#      94
#      95   # forward seq_length characters through the net and fetch gradient
# ---> 96   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      97   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      98   if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# <ipython-input-12-4786ea18ee23> in lossFun(inputs, targets, hprev)
#      52     dWxh += np.dot(dhraw, xs[t].T)
#      53     dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 54     dhnext = np.dot(Whh.T, dhraw)
#      55   for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#      56     np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
#
# KeyboardInterrupt:

# %% [markdown]
# I stopped the above compilation as it takes quite a while to generate meaninful text - and sometimes it doesn't seem to converge at all. Here is the output from an implementation I had running for a  day or two that got down to about 16 for its loss.
# ```
# Oxprensur Machine Learning Based Comparison Imagepredalyic Problem A Machine Learning Shidenticing With Stomement Machine
# Genetional Translingl Data O
# Tby Of Panadigunoous Of Machine Learning Approach
# Machine Learning Approaches And Ancerxards
# Applications
# Ortamenopforcher Image Of And Comparison Hen
# Bytesca For Dete
# Semapt Recognition
# Neural Ontropicaty Stvediction
# Thance Resules Of Machinelearning Based And Machine Learning
# Ma
# Rward Algorithms
# Thek Support Vector Machine Learning Toces
# Survey
# Subperai Scalistose Machine Learning
# Classer Ald Optimization
# Spatsimentar Scanisys
# Twarites In Machine Learning For Algorithms
# Realtime S Forildetion For Support Vector Machine Learning Techniques For The Laond Machine Learning For S
# Syppbys
# Mumporaty Researchon Using Of Temporing
# Entruasian Designs Spevied Alghid Machine Learning
# Clesit A Dizen Interaninergopers
# Machine Learning
# D
# Operpne Mencal Work2Bated Athito Mativing Thootimic Optoraty For Machine Learning Methodent Methods In Dete Detection Of The Ancherch Of Contratecompu
# Hacingar Proborion
# Machine Learning In Metric Learning Transif Trassing An Learning
# Machine Learning Audomement Machine Learning Of Machine Learning T
# Ttymane Learning Coneftrand An Application For Mmfes On Undersec Auport Text Machine Learning A Machine Learning With Stalsaby Data Misuse Contronimic
# Rsenticing Machineleseratigg
# Machinelearning Of Vector
# Machine Learning
# Hungersing On Machine Learning And Activity
# Approach To Trugbal Machine Learni
# Rcemative Learning
# Machine Learning And Compilianc User Introppshibution Of Brain Berial Distoneer Machine Learning
# Discovery Descnessow Of Ant Seqmen
# Oventicing Using Recognstimessing Practical Frainetation
# Mesticabily For Parxam Experimaphitist Besk Coxican
# Machine Learning Bos Automated Machine Le
# Fxamentle Image Of Machine Learning Gave Trapean Schemass Of Machine Learning Of Methods Inty On Combinion Gane Technical Deabficimation Classaletrati
# Esintiafforcemental Nerkase Deterabe Optimization Agversitoraling
# A For Decision Techniques And Optimization For Usey In Machine Learning Corsed Machi
# Onedential Machine Learning
# Detection
# Drepoutivelearning Machine Learning
# Computtess Design Re6Aition To By Intempregressir Tomation
# Suportiva Contere
# Raph Incrotelaxics Ylame Tring Code
# Anemoriomative Reperimity In Paraller
# Munt Langouupmi Plediction Of Machine Learning
# Predicting Prowibley Increman
# Ecosting Machine Learning
# Predict Learning And Smanced
# Machine Learning
# Data With Machine Learning Toateraby Ougcing Word Feature Ussifbees
# Jachi Elar
# Dations
# Analysis Of Liagn Twictite Classification
# Patferetistic Prospe Identificies Clamngenoun
# Progmaris
# Machine Learning For Anpreaching Methoduntac
# Ocion Ad Applisition Reclasy Envinids
# Quantsys A Otsum Mazining A Machine Learning
# Machine Learning
# Machine Learning
# Extraction
# Machine Learning Appro
# Iches Using Machine Learning Pprssmase To Machine Learning Approach To Filteral Progrom Om Feremble Identifica Optiman Enviroptimization Of The Use In
# ```
#
# As you can see, they are generally quite nonsensical. Although, the simple RNN does latch onto a few words that it has learned based on character sequences alone which is really cool! It has basically learned a tiny and very focused bit of the english language.

# %% [markdown]
# # Word Level RNN
# The second implementation uses [Denny Brit'z Word level model](https://github.com/dennybritz/rnn-tutorial-rnnlm)

# %%
import csv
import itertools
import operator
import nltk
import sys
from datetime import datetime

# %%
# Chops the stream of titles into an array of titles based on new line characters
titles = cleaned.split("\n")
titles[0]
# Out:
# 'scikitlearn machine learning in python'

# %%
unknown_token = "UNKNOWN_TOKEN"
title_start_token = "SENTENCE_START"
title_end_token = "SENTENCE_END"

# %%
# Add the start and end token to the title
titles = ["%s %s %s" % (title_start_token, x, title_end_token) for x in titles]

# %%
# Ensure that nltk has the punkt package
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokenized_titles = [nltk.word_tokenize(t) for t in titles]

# %%
word_freq = nltk.FreqDist(itertools.chain(*tokenized_titles))
print("Found %d unique words tokens." % len(word_freq.items()))
# Out:
# Found 1841 unique words tokens.

# %%
vocabulary_size=2000#len(word_freq.items())
vocab = word_freq.most_common(vocabulary_size-1)
index_to_word = [x[0] for x in vocab]
index_to_word.append(unknown_token)
word_to_index = dict([(w,i) for i,w in enumerate(index_to_word)])

# %%
print("Using vocabulary size %d." % vocabulary_size)
print("The least frequent word in our vocabulary is '%s' and appeared %d times." % (vocab[-1][0], vocab[-1][1]))
# Out:
# Using vocabulary size 2000.
# The least frequent word in our vocabulary is 'ethical' and appeared 1 times.

# %%
# Replace all words not in our vocabulary with the unknown token
for i, sent in enumerate(tokenized_titles):
    tokenized_titles[i] = [w if w in word_to_index else unknown_token for w in sent]

# %%
print("\nExample sentence: '%s'" % titles[0])
print("\nExample sentence after Pre-processing: '%s'" % tokenized_titles[0])
# Out:
# Example sentence: 'SENTENCE_START scikitlearn machine learning in python SENTENCE_END'
#
# Example sentence after Pre-processing: '['SENTENCE_START', 'scikitlearn', 'machine', 'learning', 'in', 'python', 'SENTENCE_END']'

# %%
# Create the training data
X_train = np.asarray([[word_to_index[w] for w in sent[:-1]] for sent in tokenized_titles])
y_train = np.asarray([[word_to_index[w] for w in sent[1:]] for sent in tokenized_titles])

# %%
# Print training data example
x_example, y_example = X_train[17], y_train[17]
print("x:\n%s\n%s" % (" ".join([index_to_word[x] for x in x_example]), x_example))
print("\ny:\n%s\n%s" % (" ".join([index_to_word[x] for x in y_example]), y_example))
# Out:
# x:
# SENTENCE_START supervised machine learning a review of classification techniques
# [0, 66, 3, 2, 7, 49, 6, 16, 18]
#
# y:
# supervised machine learning a review of classification techniques SENTENCE_END
# [66, 3, 2, 7, 49, 6, 16, 18, 1]

# %%
def softmax(x):
    xt = np.exp(x - np.max(x))
    return xt / np.sum(xt)

# %%
class RNNNumpy:
    
    def __init__(self, word_dim, hidden_dim=100, bptt_truncate=4):
        # Assign instance variables
        self.word_dim = word_dim
        self.hidden_dim = hidden_dim
        self.bptt_truncate = bptt_truncate
        # Randomly initialize the network parameters
        self.U = np.random.uniform(-np.sqrt(1./word_dim), np.sqrt(1./word_dim), (hidden_dim, word_dim))
        self.V = np.random.uniform(-np.sqrt(1./hidden_dim), np.sqrt(1./hidden_dim), (word_dim, hidden_dim))
        self.W = np.random.uniform(-np.sqrt(1./hidden_dim), np.sqrt(1./hidden_dim), (hidden_dim, hidden_dim))

# %%
def forward_propagation(self, x):
    # The total number of time steps
    T = len(x)
    # During forward propagation we save all hidden states in s because need them later.
    # We add one additional element for the initial hidden, which we set to 0
    s = np.zeros((T + 1, self.hidden_dim))
    s[-1] = np.zeros(self.hidden_dim)
    # The outputs at each time step. Again, we save them for later.
    o = np.zeros((T, self.word_dim))
    # For each time step...
    for t in np.arange(T):
        # Note that we are indxing U by x[t]. This is the same as multiplying U with a one-hot vector.
        s[t] = np.tanh(self.U[:,x[t]] + self.W.dot(s[t-1]))
        o[t] = softmax(self.V.dot(s[t]))
    return [o, s]

RNNNumpy.forward_propagation = forward_propagation

def predict(self, x):
    # Perform forward propagation and return index of the highest score
    o, s = self.forward_propagation(x)
    return np.argmax(o, axis=1)

RNNNumpy.predict = predict

# %%
np.random.seed(10)
model = RNNNumpy(vocabulary_size)
o, s = model.forward_propagation(X_train[10])
print(o.shape)
print(o)
# Out:
# (5, 2000)
# [[0.00050094 0.00049585 0.00050577 ... 0.00050363 0.00049082 0.00049915]
#  [0.00050011 0.00050381 0.00050253 ... 0.00050514 0.00050839 0.0005072 ]
#  [0.00050025 0.00049864 0.00049696 ... 0.00049498 0.00049688 0.00050403]
#  [0.00050167 0.00050213 0.00049959 ... 0.00049484 0.00050239 0.00050337]
#  [0.00050468 0.00049741 0.00050422 ... 0.00050882 0.00050223 0.00051026]]

# %%
predictions = model.predict(X_train[10])
print(predictions.shape)
print(predictions)
# Out:
# (5,)
# [1755  202    3 1314 1300]

# %%
def calculate_total_loss(self, x, y):
    L = 0
    # For each sentence...
    for i in np.arange(len(y)):
        o, s = self.forward_propagation(x[i])
        # We only care about our prediction of the "correct" words
        correct_word_predictions = o[np.arange(len(y[i])), y[i]]
        # Add to the loss based on how off we were
        L += -1 * np.sum(np.log(correct_word_predictions))
    return L

def calculate_loss(self, x, y):
    # Divide the total loss by the number of training examples
    N = np.sum((len(y_i) for y_i in y))
    return self.calculate_total_loss(x,y)/N

RNNNumpy.calculate_total_loss = calculate_total_loss
RNNNumpy.calculate_loss = calculate_loss

# %%
# Limit to 1000 examples to save time
print("Expected Loss for random predictions: %f" % np.log(vocabulary_size))
print("Actual loss: %f" % model.calculate_loss(X_train[:1000], y_train[:1000]))
# Out:
# Expected Loss for random predictions: 7.600902
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# Actual loss: 7.601434

# %%
def bptt(self, x, y):
    T = len(y)
    # Perform forward propagation
    o, s = self.forward_propagation(x)
    # We accumulate the gradients in these variables
    dLdU = np.zeros(self.U.shape)
    dLdV = np.zeros(self.V.shape)
    dLdW = np.zeros(self.W.shape)
    delta_o = o
    delta_o[np.arange(len(y)), y] -= 1.
    # For each output backwards...
    for t in np.arange(T)[::-1]:
        dLdV += np.outer(delta_o[t], s[t].T)
        # Initial delta calculation
        delta_t = self.V.T.dot(delta_o[t]) * (1 - (s[t] ** 2))
        # Backpropagation through time (for at most self.bptt_truncate steps)
        for bptt_step in np.arange(max(0, t-self.bptt_truncate), t+1)[::-1]:
            # print "Backpropagation step t=%d bptt step=%d " % (t, bptt_step)
            dLdW += np.outer(delta_t, s[bptt_step-1])              
            dLdU[:,x[bptt_step]] += delta_t
            # Update delta for next step
            delta_t = self.W.T.dot(delta_t) * (1 - s[bptt_step-1] ** 2)
    return [dLdU, dLdV, dLdW]

RNNNumpy.bptt = bptt

# %%
def gradient_check(self, x, y, h=0.001, error_threshold=0.01):
    # Calculate the gradients using backpropagation. We want to checker if these are correct.
    bptt_gradients = model.bptt(x, y)
    # List of all parameters we want to check.
    model_parameters = ['U', 'V', 'W']
    # Gradient check for each parameter
    for pidx, pname in enumerate(model_parameters):
        # Get the actual parameter value from the mode, e.g. model.W
        parameter = operator.attrgetter(pname)(self)
        print("Performing gradient check for parameter %s with size %d." % (pname, np.prod(parameter.shape)))
        # Iterate over each element of the parameter matrix, e.g. (0,0), (0,1), ...
        it = np.nditer(parameter, flags=['multi_index'], op_flags=['readwrite'])
        while not it.finished:
            ix = it.multi_index
            # Save the original value so we can reset it later
            original_value = parameter[ix]
            # Estimate the gradient using (f(x+h) - f(x-h))/(2*h)
            parameter[ix] = original_value + h
            gradplus = model.calculate_total_loss([x],[y])
            parameter[ix] = original_value - h
            gradminus = model.calculate_total_loss([x],[y])
            estimated_gradient = (gradplus - gradminus)/(2*h)
            # Reset parameter to original value
            parameter[ix] = original_value
            # The gradient for this parameter calculated using backpropagation
            backprop_gradient = bptt_gradients[pidx][ix]
            # calculate The relative error: (|x - y|/(|x| + |y|))
            relative_error = np.abs(backprop_gradient - estimated_gradient)/(np.abs(backprop_gradient) + np.abs(estimated_gradient))
            # If the error is to large fail the gradient check
            if relative_error > error_threshold:
                print("Gradient Check ERROR: parameter=%s ix=%s" % (pname, ix))
                print("+h Loss: %f" % gradplus)
                print("-h Loss: %f" % gradminus)
                print("Estimated_gradient: %f" % estimated_gradient)
                print("Backpropagation gradient: %f" % backprop_gradient)
                print("Relative Error: %f" % relative_error)
                return 
            it.iternext()
        print("Gradient check for parameter %s passed." % (pname))

RNNNumpy.gradient_check = gradient_check

# To avoid performing millions of expensive calculations we use a smaller vocabulary size for checking.
grad_check_vocab_size = 100
np.random.seed(10)
word_model = RNNNumpy(grad_check_vocab_size, 10, bptt_truncate=1000)
word_model.gradient_check([0,1,2,3], [1,2,3,4])
# Out:
# Performing gradient check for parameter U with size 1000.
# Gradient Check ERROR: parameter=U ix=(0, 0)
# +h Loss: 30.432536
# -h Loss: 30.432536
# Estimated_gradient: 0.000000
# Backpropagation gradient: -0.177072
# Relative Error: 1.000000

# %%
# Performs one step of SGD.
def numpy_sdg_step(self, x, y, learning_rate):
    # Calculate the gradients
    dLdU, dLdV, dLdW = self.bptt(x, y)
    # Change parameters according to gradients and learning rate
    self.U -= learning_rate * dLdU
    self.V -= learning_rate * dLdV
    self.W -= learning_rate * dLdW

RNNNumpy.sgd_step = numpy_sdg_step

# %%
# Outer SGD Loop
# - model: The RNN model instance
# - X_train: The training data set
# - y_train: The training data labels
# - learning_rate: Initial learning rate for SGD
# - nepoch: Number of times to iterate through the complete dataset
# - evaluate_loss_after: Evaluate the loss after this many epochs
def train_with_sgd(model, X_train, y_train, learning_rate=0.005, nepoch=100, evaluate_loss_after=5):
    # We keep track of the losses so we can plot them later
    losses = []
    num_examples_seen = 0
    for epoch in range(nepoch):
        # Optionally evaluate the loss
        if (epoch % evaluate_loss_after == 0):
            loss = model.calculate_loss(X_train, y_train)
            losses.append((num_examples_seen, loss))
            time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            print("%s: Loss after num_examples_seen=%d epoch=%d: %f" % (time, num_examples_seen, epoch, loss))
            # Adjust the learning rate if loss increases
            if (len(losses) > 1 and losses[-1][1] > losses[-2][1]):
                learning_rate = learning_rate * 0.5  
                print("Setting learning rate to %f" % learning_rate)
            sys.stdout.flush()
        # For each training example...
        for i in range(len(y_train)):
            # One SGD step
            model.sgd_step(X_train[i], y_train[i], learning_rate)
            num_examples_seen += 1

# %%
np.random.seed(10)
word_model = RNNNumpy(vocabulary_size)
# %timeit model.sgd_step(X_train[10], y_train[10], 0.005)
# Out:
# 100 loops, best of 3: 8.06 ms per loop

# %%
np.random.seed(10)
model = RNNNumpy(vocabulary_size)
losses = train_with_sgd(model, X_train[:1000], y_train[:1000], nepoch=100, evaluate_loss_after=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# 2019-05-25 15:41:43: Loss after num_examples_seen=0 epoch=0: 7.601434
# 2019-05-25 15:42:00: Loss after num_examples_seen=950 epoch=1: 5.100385
# 2019-05-25 15:42:17: Loss after num_examples_seen=1900 epoch=2: 4.883128
# 2019-05-25 15:42:34: Loss after num_examples_seen=2850 epoch=3: 4.780716
# 2019-05-25 15:42:51: Loss after num_examples_seen=3800 epoch=4: 4.696207
# 2019-05-25 15:43:09: Loss after num_examples_seen=4750 epoch=5: 4.619038
# 2019-05-25 15:43:26: Loss after num_examples_seen=5700 epoch=6: 4.552703
# 2019-05-25 15:43:43: Loss after num_examples_seen=6650 epoch=7: 4.491730
# 2019-05-25 15:44:00: Loss after num_examples_seen=7600 epoch=8: 4.434393
# 2019-05-25 15:44:18: Loss after num_examples_seen=8550 epoch=9: 4.380702
# 2019-05-25 15:44:35: Loss after num_examples_seen=9500 epoch=10: 4.329521
# 2019-05-25 15:44:53: Loss after num_examples_seen=10450 epoch=11: 4.280264
# 2019-05-25 15:45:10: Loss after num_examples_seen=11400 epoch=12: 4.233772
# 2019-05-25 15:45:28: Loss after num_examples_seen=12350 epoch=13: 4.191475
# 2019-05-25 15:45:45: Loss after num_examples_seen=13300 epoch=14: 4.154720
# 2019-05-25 15:46:02: Loss after num_examples_seen=14250 epoch=15: 4.105941
# 2019-05-25 15:46:20: Loss after num_examples_seen=15200 epoch=16: 4.067841
# 2019-05-25 15:46:37: Loss after num_examples_seen=16150 epoch=17: 4.036423
# 2019-05-25 15:46:54: Loss after num_examples_seen=17100 epoch=18: 3.982951
# 2019-05-25 15:47:12: Loss after num_examples_seen=18050 epoch=19: 3.947387
# 2019-05-25 15:47:29: Loss after num_examples_seen=19000 epoch=20: 3.915304
# 2019-05-25 15:47:46: Loss after num_examples_seen=19950 epoch=21: 3.888233
# 2019-05-25 15:48:03: Loss after num_examples_seen=20900 epoch=22: 3.858850
# 2019-05-25 15:48:21: Loss after num_examples_seen=21850 epoch=23: 3.827078
# 2019-05-25 15:48:38: Loss after num_examples_seen=22800 epoch=24: 3.806026
# 2019-05-25 15:48:55: Loss after num_examples_seen=23750 epoch=25: 3.791999
# 2019-05-25 15:49:12: Loss after num_examples_seen=24700 epoch=26: 3.776599
# 2019-05-25 15:49:29: Loss after num_examples_seen=25650 epoch=27: 3.760362
# 2019-05-25 15:49:47: Loss after num_examples_seen=26600 epoch=28: 3.751018
# 2019-05-25 15:50:04: Loss after num_examples_seen=27550 epoch=29: 3.757270
# Setting learning rate to 0.002500
# 2019-05-25 15:50:22: Loss after num_examples_seen=28500 epoch=30: 3.640106
# 2019-05-25 15:50:39: Loss after num_examples_seen=29450 epoch=31: 3.625389
# 2019-05-25 15:50:57: Loss after num_examples_seen=30400 epoch=32: 3.616406
# 2019-05-25 15:51:14: Loss after num_examples_seen=31350 epoch=33: 3.613986
# 2019-05-25 15:51:31: Loss after num_examples_seen=32300 epoch=34: 3.610226
# 2019-05-25 15:51:48: Loss after num_examples_seen=33250 epoch=35: 3.601274
# 2019-05-25 15:52:06: Loss after num_examples_seen=34200 epoch=36: 3.594444
# 2019-05-25 15:52:23: Loss after num_examples_seen=35150 epoch=37: 3.587431
# 2019-05-25 15:52:40: Loss after num_examples_seen=36100 epoch=38: 3.595749
# Setting learning rate to 0.001250
# 2019-05-25 15:52:57: Loss after num_examples_seen=37050 epoch=39: 3.534395
# 2019-05-25 15:53:14: Loss after num_examples_seen=38000 epoch=40: 3.523400
# 2019-05-25 15:53:32: Loss after num_examples_seen=38950 epoch=41: 3.510381
# 2019-05-25 15:53:49: Loss after num_examples_seen=39900 epoch=42: 3.500720
# 2019-05-25 15:54:06: Loss after num_examples_seen=40850 epoch=43: 3.495431
# 2019-05-25 15:54:23: Loss after num_examples_seen=41800 epoch=44: 3.490556
# 2019-05-25 15:54:41: Loss after num_examples_seen=42750 epoch=45: 3.488818
# 2019-05-25 15:54:58: Loss after num_examples_seen=43700 epoch=46: 3.485845
# 2019-05-25 15:55:15: Loss after num_examples_seen=44650 epoch=47: 3.483638
# 2019-05-25 15:55:33: Loss after num_examples_seen=45600 epoch=48: 3.481622
# 2019-05-25 15:55:51: Loss after num_examples_seen=46550 epoch=49: 3.478715
# 2019-05-25 15:56:08: Loss after num_examples_seen=47500 epoch=50: 3.477929
# 2019-05-25 15:56:26: Loss after num_examples_seen=48450 epoch=51: 3.479510
# Setting learning rate to 0.000625
# 2019-05-25 15:56:43: Loss after num_examples_seen=49400 epoch=52: 3.429259
# 2019-05-25 15:57:00: Loss after num_examples_seen=50350 epoch=53: 3.424342
# 2019-05-25 15:57:17: Loss after num_examples_seen=51300 epoch=54: 3.418742
# 2019-05-25 15:57:35: Loss after num_examples_seen=52250 epoch=55: 3.414435
# 2019-05-25 15:57:52: Loss after num_examples_seen=53200 epoch=56: 3.410370
# 2019-05-25 15:58:09: Loss after num_examples_seen=54150 epoch=57: 3.406576
# 2019-05-25 15:58:27: Loss after num_examples_seen=55100 epoch=58: 3.403000
# 2019-05-25 15:58:44: Loss after num_examples_seen=56050 epoch=59: 3.400307
# 2019-05-25 15:59:01: Loss after num_examples_seen=57000 epoch=60: 3.398605
# 2019-05-25 15:59:19: Loss after num_examples_seen=57950 epoch=61: 3.397894
# 2019-05-25 15:59:36: Loss after num_examples_seen=58900 epoch=62: 3.398161
# Setting learning rate to 0.000313
# 2019-05-25 15:59:53: Loss after num_examples_seen=59850 epoch=63: 3.350161
# 2019-05-25 16:00:11: Loss after num_examples_seen=60800 epoch=64: 3.343019
# 2019-05-25 16:00:29: Loss after num_examples_seen=61750 epoch=65: 3.338262
# 2019-05-25 16:00:46: Loss after num_examples_seen=62700 epoch=66: 3.335535
# 2019-05-25 16:01:04: Loss after num_examples_seen=63650 epoch=67: 3.333591
# 2019-05-25 16:01:22: Loss after num_examples_seen=64600 epoch=68: 3.331748
# 2019-05-25 16:01:39: Loss after num_examples_seen=65550 epoch=69: 3.329749
# 2019-05-25 16:01:56: Loss after num_examples_seen=66500 epoch=70: 3.327510
# 2019-05-25 16:02:14: Loss after num_examples_seen=67450 epoch=71: 3.324991
# 2019-05-25 16:02:31: Loss after num_examples_seen=68400 epoch=72: 3.322275
# 2019-05-25 16:02:48: Loss after num_examples_seen=69350 epoch=73: 3.319588
# 2019-05-25 16:03:06: Loss after num_examples_seen=70300 epoch=74: 3.317079
# 2019-05-25 16:03:23: Loss after num_examples_seen=71250 epoch=75: 3.314758
# 2019-05-25 16:03:40: Loss after num_examples_seen=72200 epoch=76: 3.312568
# 2019-05-25 16:03:58: Loss after num_examples_seen=73150 epoch=77: 3.310483
# 2019-05-25 16:04:15: Loss after num_examples_seen=74100 epoch=78: 3.308518
# 2019-05-25 16:04:32: Loss after num_examples_seen=75050 epoch=79: 3.306699
# 2019-05-25 16:04:49: Loss after num_examples_seen=76000 epoch=80: 3.305048
# 2019-05-25 16:05:07: Loss after num_examples_seen=76950 epoch=81: 3.303578
# 2019-05-25 16:05:24: Loss after num_examples_seen=77900 epoch=82: 3.302305
# 2019-05-25 16:05:42: Loss after num_examples_seen=78850 epoch=83: 3.301242
# 2019-05-25 16:05:59: Loss after num_examples_seen=79800 epoch=84: 3.300367
# 2019-05-25 16:06:17: Loss after num_examples_seen=80750 epoch=85: 3.299641
# 2019-05-25 16:06:34: Loss after num_examples_seen=81700 epoch=86: 3.299042
# 2019-05-25 16:06:52: Loss after num_examples_seen=82650 epoch=87: 3.298558
# 2019-05-25 16:07:09: Loss after num_examples_seen=83600 epoch=88: 3.298173
# 2019-05-25 16:07:26: Loss after num_examples_seen=84550 epoch=89: 3.297873
# 2019-05-25 16:07:43: Loss after num_examples_seen=85500 epoch=90: 3.297648
# 2019-05-25 16:08:01: Loss after num_examples_seen=86450 epoch=91: 3.297494
# 2019-05-25 16:08:18: Loss after num_examples_seen=87400 epoch=92: 3.297409
# 2019-05-25 16:08:35: Loss after num_examples_seen=88350 epoch=93: 3.297387
# 2019-05-25 16:08:52: Loss after num_examples_seen=89300 epoch=94: 3.297422
# Setting learning rate to 0.000156
# 2019-05-25 16:09:10: Loss after num_examples_seen=90250 epoch=95: 3.253089
# 2019-05-25 16:09:27: Loss after num_examples_seen=91200 epoch=96: 3.247362
# 2019-05-25 16:09:44: Loss after num_examples_seen=92150 epoch=97: 3.243674
# 2019-05-25 16:10:01: Loss after num_examples_seen=93100 epoch=98: 3.241192
# 2019-05-25 16:10:18: Loss after num_examples_seen=94050 epoch=99: 3.239189

# %%
def generate_sentence(model):
    # We start the sentence with the start token
    new_sentence = [word_to_index[sentence_start_token]]
    # Repeat until we get an end token
    while not new_sentence[-1] == word_to_index[sentence_end_token]:
        next_word_probs = model.forward_propagation(new_sentence)
        #print(next_word_probs[0][-1])
        #print(max(next_word_probs[0][-1]))
        sampled_word = word_to_index[unknown_token]
        # We don't want to sample unknown words
        while sampled_word == word_to_index[unknown_token]:
            samples = np.random.multinomial(1, next_word_probs[0][-1])
            sampled_word = np.argmax(samples)
        new_sentence.append(sampled_word)
    sentence_str = [index_to_word[x] for x in new_sentence[1:-1]]
    return sentence_str

num_sentences = 15
senten_min_length = 5

for i in range(num_sentences):
    sent = []
    # We want long sentences, not sentences with one or two words
    while len(sent) < senten_min_length:
        sent = generate_sentence(model)
    print(" ".join(sent).title())
# Out:
# Networked Inference And Quantitative Classification Using Ubiquitous And Machine Learning Algorithm
# Machine Learning Based Perspectives Applications
# Support Vector Machine For Library Machine Authentication In Data
# Ptsd Bayesian Resolution An Human Adaptation Using Machine Learning
# Data Mining Machine Learning On Deep Classification
# A Study Of Practice And Thinks In Classification Of Supervised Learning And Sites Using Machine Learning
# Interactive Machine Learning In Twitter
# Machine Learning Techniques For Reasoning Interpolation
# A Machine Learning Approach To Spark Page Of Permission Carbon Space And Application
# Machine Learning In Prediction Radios Svmlight Adhoc Umls
# Detecting Ensemble Methods And Machine Learning Techniques
# The Practical System In Evaluating Machine Learning
# Contentbased Coadaptive For Patternmatch Breakage Ngram Sense Using Machine Learning
# Network Exploration Quantum Science Classification Tool Selection And Interactive Machine Learning And Language Support
# Identification Genomescale Course From A Transversals Smallfootprint Machine Learning Approaches Sparse Server

# %% [markdown]
# # LSTM
#  This is the [Beginners guide to text generation with LSTM](https://www.kaggle.com/shivamb/beginners-guide-to-text-generation-using-lstms) implementation

# %%
import tensorflow as tf
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import keras.utils as ku 


from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(2)
seed(1)

import os 

import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
corpus = cleaned.split("\n")
print(corpus[:10])
# Out:
# ['scikitlearn machine learning in python', 'pattern recognition and machine learning', 'gaussian processes in machine learning', 'machine learning in automated text categorization', 'machine learning', 'thumbs up sentiment classification using machine learning techniques', 'ensemble methods in machine learning', 'c4 5 programs for machine learning', 'uci machine learning repository', 'data mining practical machine learning tools and techniques']

# %%
tokenizer = Tokenizer()

def get_sequence_of_tokens(corpus):
    ## tokenization
    tokenizer.fit_on_texts(corpus)
    total_words = len(tokenizer.word_index) + 1
    
    ## convert data to sequence of tokens 
    input_sequences = []
    for line in corpus:
        token_list = tokenizer.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
    return input_sequences, total_words

inp_sequences, total_words = get_sequence_of_tokens(corpus)
print(total_words)
inp_sequences[:10]
# Out:
# 1840
# [[161, 2],
#  [161, 2, 1],
#  [161, 2, 1, 7],
#  [161, 2, 1, 7, 137],
#  [162, 42],
#  [162, 42, 4],
#  [162, 42, 4, 2],
#  [162, 42, 4, 2, 1],
#  [138, 163],
#  [138, 163, 7]]

# %%
def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))
    
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = ku.to_categorical(label, num_classes=total_words)
    return predictors, label, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(inp_sequences)
print(max_sequence_len)
# Out:
# 21

# %%
def create_model(max_sequence_len, total_words):
    input_len = max_sequence_len - 1
    model = Sequential()
    
    # Add Input Embedding Layer
    model.add(Embedding(total_words, 10, input_length=input_len))
    
    # Add Hidden Layer 1 - LSTM Layer
    model.add(LSTM(100))
    model.add(Dropout(0.1))
    
    # Add Output Layer
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    return model

lstm_model = create_model(max_sequence_len, total_words)
lstm_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 20, 10)            18400
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               44400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1840)              185840
# =================================================================
# Total params: 248,640
# Trainable params: 248,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(predictors, label, epochs=100, verbose=5)
# Out:
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100

# %%
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict_classes(token_list, verbose=0)
        
        output_word = ""
        for word,index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " "+output_word
    return seed_text.title()

# %%
print (generate_text("", 5, lstm_model, max_sequence_len))
print (generate_text("euclidean", 4, lstm_model, max_sequence_len))
print (generate_text("generative", 5, lstm_model, max_sequence_len))
print (generate_text("ground breaking", 5, lstm_model, max_sequence_len))
print (generate_text("new", 4, lstm_model, max_sequence_len))
print (generate_text("understanding", 5, lstm_model, max_sequence_len))
print (generate_text("long short term memory", 6, lstm_model, max_sequence_len))
print (generate_text("LSTM", 6, lstm_model, max_sequence_len))
print (generate_text("a", 5, lstm_model, max_sequence_len))
print (generate_text("anomaly", 5, lstm_model, max_sequence_len))
print (generate_text("data", 7, lstm_model, max_sequence_len))
print (generate_text("designing", 7, lstm_model, max_sequence_len))
print (generate_text("reinforcement", 7, lstm_model, max_sequence_len))
# Out:
#  Inference Algorithms For Machine Learning
# Euclidean Inference Algorithms For Machine
# Generative Optimization And Machine Learning In
# Ground Breaking Inference Algorithms For Machine Learning
# New Forests A Unified Framework
# Understanding Machine Learning For Sledgehammer Microarray
# Long Short Term Memory Classifications With Machine Learning Classifiers For
# Lstm Network Benchmarking Machine Learning Algorithms For
# A Machine Learning Approach To Coreference
# Anomaly Detection Using Machine Learning Techniques
# Data Mining And Machine Learning In Cybersecurity Biologytowards
# Designing Inference Algorithms For Machine Learning Techniques For
# Reinforcement Learning Chapelle O Et Al Eds 2006

# %% [markdown]
# # Results
# When trying to analyse each different method I used the number of titles that made sense from start to finish and whether a title contained a sub-string that made sense. I named these two metrics **Coherent Titles* and **Coherent Sub-strings**.
#
# I then generated 15 titles with each model and calculated the following results:
#
# |Model|Coherent Titles|Coherent Sub-strings|
# |------|-----|-----|
# |Char RNN|6.67%|6.67%|
# |Word RNN|40%|53%|
# |LSTM|60%|100%|
#
# Its apparent that the LSTM outperforms  the RNNs, but that was to be expected. I think the word level RNN is actually quite good, and the char level one can definitely be improved upon. Also, the dataset is quite small. With a large corpus I think the results would likely be improved.
#
# However, a more formalised method for comparing the models is definitely necessary for further research.
#
# # Going Forward
# I think a possible method of comparing the different models would be to use a language model that can indicidate whether a sentence makes sense to some degree. Then that could be used on the generated titles in order to extrapolate some more meaningful and reproducible results. I was advised by my lecturer that a possible method of doing this was to use something like [Google Ngram](https://books.google.com/ngrams/info), and check whether a title or a substring of a title has been previously used to a certain degree. If it has, then it likely makes some sense.
#
# The parameters for the different implementations can definitely also be experimented with in order to better understand the impact on the final titles.
#
# I was also advised that an interesting area of research would be to generate a title for your paper (or writings) based on the abstract (or some subsection of your writings).  This would very likely lead to titles that are more related to the actual content.
#
# This was a very fun and interesting experience, and was inspired by the following:
# * [Harry Potter and the Portrait of what Looked like a Large Pile of Ash by Botnik ](https://botnik.org/content/harry-potter.html)
# * [King James Programming](https://kingjamesprogramming.tumblr.com/)
# *[Alice in Elsinore](https://www.eblong.com/zarf/markov/alice_in_elsinore.txt) from [Fun with Markov Chains](https://www.eblong.com/zarf/markov/)
# * [Stack Exchange Simulator](https://se-simulator.lw1.at/)
# * [Pun Generation with Suprise](https://github.com/hhexiy/pungen)
